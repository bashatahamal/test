# %% [markdown]
# ### **INIT**

# %%
# %%capture
# !pip install q tensorflow==2.1
# !pip install q keras==2.3.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import pickle
import matplotlib.pyplot as plt
import random
import itertools
saved_output = []

def plot_gallery(images, titles, n_row=3, n_col=4):
    plt.figure(1, figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        r = random.randint(1,len(images))
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[r], cmap=plt.cm.gray)
        plt.title(char_list_nameonly[titles[r]], size=12)
        plt.xticks(())
        plt.yticks(())
    plt.show()
    #plt.savefig("predict.png")

def plot_gallery_norand(images, titles, n_row=3, n_col=4):
    plt.figure(1, figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
#         r = random.randint(1,len(images))
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i], cmap=plt.cm.gray)
        plt.title(char_list_nameonly[titles[i]], size=12)
        plt.xticks(())
        plt.yticks(())
    plt.show()

def plot_gallery_predict(images, predict, true, n_row=3, n_col=4):
    plt.figure(1, figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        r = random.randint(1,len(images))
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[r], cmap=plt.cm.gray)
        plt.title('p:' + str(predict[r]) + '   t:' + str(true[r]), size=12)
        plt.xticks(())
        plt.yticks(())
    plt.show()
    #plt.savefig("predict.png")

# %%
loc_collection = '/content/drive/My Drive/Notebook/Auto_Collection_Gray/'
shape = 'Square'
# shape = 'No_Margin'
char_list_nameonly = [
    'Alif‬', 'Bā’', 'Tā’', 'Ṡā’‬', 'Jīm', 'Ḥā’‬', 'Khā’‬',
    'Dāl‬', 'Żāl‬', 'Rā’‬', 'zai‬', 'sīn‬', 'syīn‬', 'ṣād',
    'ḍād', 'ṭā’‬', 'ẓȧ’‬', '‘ain', 'gain‬', 'fā’‬', 'qāf‬',
    'kāf‬', 'lām‬', 'mīm‬', 'nūn‬', 'wāw‬', 'hā’‬', 'yā’‬'
]
import pickle
filename = '/content/drive/My Drive/Notebook/sameratio_keepform.pkl'
sameratio_keepform = pickle.load(open(filename, 'rb'))
filename = '/content/drive/My Drive/Notebook/diffratio_keepform.pkl'
diffratio_keepform = pickle.load(open(filename, 'rb'))
filename = '/content/drive/My Drive/Notebook/sameratio_diffform.pkl'
sameratio_diffform = pickle.load(open(filename, 'rb'))
filename = '/content/drive/My Drive/Notebook/diffratio_diffform.pkl'
diffratio_diffform = pickle.load(open(filename, 'rb'))

print(sameratio_keepform.keys())
print(diffratio_keepform.keys())
print(sameratio_diffform.keys())
print(diffratio_diffform.keys())
# Out:
# dict_keys(['sk_32_bh', 'sk_32_bw', 'sk_sibh', 'sk_sibw', 'sk_largest'])
# dict_keys(['dk_32', 'dk_sibh', 'dk_sibw', 'dk_libh', 'dk_libw'])
# dict_keys(['sd_32', 'sd_smallest', 'sd_largest'])
# dict_keys(['dd_32', 'dd_sibh', 'dd_sibw', 'dd_libh', 'dd_libw'])

# %%
data_dk = []
label_dk = []
for i in range(0,28):
    for x in range(len(diffratio_keepform['dk_32'][i])):
        gd = diffratio_keepform['dk_32'][i][x]
        data_dk.append(diffratio_keepform['dk_32'][i][x])
        label_dk.append(i)
data_dk = np.array(data_dk)
label_dk = np.array(label_dk)

data_sk = []
data_sk_temp = []
label_sk = []
for i in range(0,28):
    for x in range(len(sameratio_keepform['sk_32_bh'][i])):
        data_sk_temp.append(sameratio_keepform['sk_32_bh'][i][x])
        label_sk.append(i)
for x in range(len(data_sk_temp)):
    h, w = data_sk_temp[x].shape
    if h and w > 32:
        img = cv2.resize(data_sk_temp[x], (32, 32))
        print(x)
    else:
        img = data_sk_temp[x]
    y = list(img.ravel())
    y = np.array(y)
    data_sk.append(y.reshape(32, 32))
data_sk = np.array(data_sk)
label_sk = np.array(label_sk)

data_sd = []
label_sd = []
for i in range(0,28):
    for x in range(len(sameratio_diffform['sd_largest'][i])):
        data_sd.append(sameratio_diffform['sd_largest'][i][x])
        label_sd.append(i)
data_sd = np.array(data_sd)
label_sd = np.array(label_sd)
data_sd_32 = []
for data in data_sd:
  data_sd_32.append(cv2.resize(data, (32,32)))
data_sd_32 = np.array(data_sd_32)
data_sd = data_sd_32

data_dd = []
label_dd = []
for i in range(0,28):
    for x in range(len(diffratio_diffform['dd_32'][i])):
        data_dd.append(diffratio_diffform['dd_32'][i][x])
        label_dd.append(i)
data_dd = np.array(data_dd)
label_dd = np.array(label_dd)
# Out:
# 1311

# %%
print('sameratio_keepform')
plot_gallery_norand(data_sk, label_sk, 1, 4)
print('diffratio_keepform')
plot_gallery_norand(data_dk, label_dk, 1, 4)
print('sameratio_diffform')
plot_gallery_norand(data_sd, label_sd, 1, 4)
print('diffratio_diffform')
plot_gallery_norand(data_dd, label_dd, 1, 4)
# Out:
# sameratio_keepform
# diffratio_keepform
# sameratio_diffform
# diffratio_diffform

# %% [markdown]
# ### **Data**

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42

dtype = 'DD'
data_train, data_test, y_train, y_test = train_test_split(
data_dd, label_dd, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %% [markdown]
# ### **Model**

# %%
from sklearn.model_selection import StratifiedKFold
from keras.utils.np_utils import to_categorical
import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
import numpy
from time import time
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
def densenet(img_shape, n_classes, f=32):
  repetitions = 6, 12, 24, 16
  
  def bn_rl_conv(x, f, k=1, s=1, p='same'):
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(f, k, strides=s, padding=p)(x)
    return x
  
  
  def dense_block(tensor, r):
    for _ in range(r):
      x = bn_rl_conv(tensor, 4*f)
      x = bn_rl_conv(x, f, 3)
      tensor = Concatenate()([tensor, x])
    return tensor
  
  
  def transition_block(x):
    x = bn_rl_conv(x, K.int_shape(x)[-1] // 2)
    x = AvgPool2D(2, strides=2, padding='same')(x)
    return x
  
  
  input = Input(img_shape)
  
  x = Conv2D(64, 7, strides=2, padding='same')(input)
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  for r in repetitions:
    d = dense_block(x, r)
    x = transition_block(d)
  
  x = GlobalAvgPool2D()(d)
  
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  return model

# %%
# %%time
input_shape = 32, 32, 1
n_classes = 28
f=12
ep = 50
bs = 16

K.clear_session()
model = densenet(input_shape, n_classes, f=f)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 64)   3200        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)     0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 8, 64)     256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 8, 8, 64)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 48)     3120        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 8, 48)     192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 8, 8, 48)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 12)     5196        re_lu_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 76)     0           max_pooling2d_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 76)     304         concatenate_1[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 8, 8, 76)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 48)     3696        re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 48)     192         conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 8, 8, 48)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 12)     5196        re_lu_4[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 88)     0           concatenate_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 88)     352         concatenate_2[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 8, 8, 88)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 48)     4272        re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 48)     192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 8, 8, 48)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 12)     5196        re_lu_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 100)    0           concatenate_2[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 100)    400         concatenate_3[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 8, 8, 100)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 48)     4848        re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 48)     192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 8, 8, 48)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 12)     5196        re_lu_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 112)    0           concatenate_3[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 112)    448         concatenate_4[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 8, 8, 112)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 48)     5424        re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 48)     192         conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 8, 8, 48)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 12)     5196        re_lu_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 124)    0           concatenate_4[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 124)    496         concatenate_5[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 8, 8, 124)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 48)     6000        re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 48)     192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 8, 8, 48)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 12)     5196        re_lu_12[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8, 8, 136)    0           concatenate_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 136)    544         concatenate_6[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 8, 8, 136)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 68)     9316        re_lu_13[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 68)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 68)     272         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 4, 4, 68)     0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 48)     3312        re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 48)     192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_15[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 4, 4, 80)     0           average_pooling2d_1[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 80)     320         concatenate_7[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 4, 4, 80)     0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 48)     3888        re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 48)     192         conv2d_17[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_17[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 4, 4, 92)     0           concatenate_7[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 92)     368         concatenate_8[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 4, 4, 92)     0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 48)     4464        re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 48)     192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_19[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 4, 4, 104)    0           concatenate_8[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 4, 4, 104)    416         concatenate_9[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 4, 4, 104)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 4, 4, 48)     5040        re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 4, 4, 48)     192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_21[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 4, 4, 116)    0           concatenate_9[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 116)    464         concatenate_10[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 4, 4, 116)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 48)     5616        re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 48)     192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_23[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 4, 4, 128)    0           concatenate_10[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 4, 4, 128)    512         concatenate_11[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 4, 4, 128)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 4, 4, 48)     6192        re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 4, 4, 48)     192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_25[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 4, 4, 140)    0           concatenate_11[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 140)    560         concatenate_12[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 4, 4, 140)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 4, 4, 48)     6768        re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 48)     192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_27[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 4, 4, 152)    0           concatenate_12[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 4, 4, 152)    608         concatenate_13[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 4, 4, 152)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 4, 4, 48)     7344        re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 4, 4, 48)     192         conv2d_29[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_29[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 4, 4, 164)    0           concatenate_13[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 164)    656         concatenate_14[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 4, 4, 164)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 48)     7920        re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 48)     192         conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_31[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 4, 4, 176)    0           concatenate_14[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 176)    704         concatenate_15[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 4, 4, 176)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 4, 4, 48)     8496        re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 4, 4, 48)     192         conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_33[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 4, 4, 188)    0           concatenate_15[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 4, 4, 188)    752         concatenate_16[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 4, 4, 188)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 4, 4, 48)     9072        re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 4, 4, 48)     192         conv2d_35[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_35[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 4, 4, 200)    0           concatenate_16[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 4, 4, 200)    800         concatenate_17[0][0]
# __________________________________________________________________________________________________
# re_lu_36 (ReLU)                 (None, 4, 4, 200)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 48)     9648        re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 4, 4, 48)     192         conv2d_37[0][0]
# __________________________________________________________________________________________________
# re_lu_37 (ReLU)                 (None, 4, 4, 48)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 12)     5196        re_lu_37[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 4, 4, 212)    0           concatenate_17[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 4, 4, 212)    848         concatenate_18[0][0]
# __________________________________________________________________________________________________
# re_lu_38 (ReLU)                 (None, 4, 4, 212)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 4, 4, 106)    22578       re_lu_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 2, 2, 106)    0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 2, 2, 106)    424         average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_39 (ReLU)                 (None, 2, 2, 106)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 2, 2, 48)     5136        re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 2, 2, 48)     192         conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_40 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_40[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 2, 2, 118)    0           average_pooling2d_2[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 2, 2, 118)    472         concatenate_19[0][0]
# __________________________________________________________________________________________________
# re_lu_41 (ReLU)                 (None, 2, 2, 118)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 2, 2, 48)     5712        re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 2, 2, 48)     192         conv2d_42[0][0]
# __________________________________________________________________________________________________
# re_lu_42 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_42[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 2, 2, 130)    0           concatenate_19[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 2, 2, 130)    520         concatenate_20[0][0]
# __________________________________________________________________________________________________
# re_lu_43 (ReLU)                 (None, 2, 2, 130)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 2, 2, 48)     6288        re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 2, 2, 48)     192         conv2d_44[0][0]
# __________________________________________________________________________________________________
# re_lu_44 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_44[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 2, 2, 142)    0           concatenate_20[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 2, 2, 142)    568         concatenate_21[0][0]
# __________________________________________________________________________________________________
# re_lu_45 (ReLU)                 (None, 2, 2, 142)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 2, 2, 48)     6864        re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 2, 2, 48)     192         conv2d_46[0][0]
# __________________________________________________________________________________________________
# re_lu_46 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_46[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 2, 2, 154)    0           concatenate_21[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 2, 2, 154)    616         concatenate_22[0][0]
# __________________________________________________________________________________________________
# re_lu_47 (ReLU)                 (None, 2, 2, 154)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 2, 2, 48)     7440        re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 2, 2, 48)     192         conv2d_48[0][0]
# __________________________________________________________________________________________________
# re_lu_48 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_48[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 2, 2, 166)    0           concatenate_22[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 2, 2, 166)    664         concatenate_23[0][0]
# __________________________________________________________________________________________________
# re_lu_49 (ReLU)                 (None, 2, 2, 166)    0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 2, 2, 48)     8016        re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 2, 2, 48)     192         conv2d_50[0][0]
# __________________________________________________________________________________________________
# re_lu_50 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_50[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 2, 2, 178)    0           concatenate_23[0][0]
#                                                                  conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 2, 2, 178)    712         concatenate_24[0][0]
# __________________________________________________________________________________________________
# re_lu_51 (ReLU)                 (None, 2, 2, 178)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 2, 2, 48)     8592        re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 2, 2, 48)     192         conv2d_52[0][0]
# __________________________________________________________________________________________________
# re_lu_52 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_52[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 2, 2, 190)    0           concatenate_24[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 2, 2, 190)    760         concatenate_25[0][0]
# __________________________________________________________________________________________________
# re_lu_53 (ReLU)                 (None, 2, 2, 190)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 2, 2, 48)     9168        re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 2, 2, 48)     192         conv2d_54[0][0]
# __________________________________________________________________________________________________
# re_lu_54 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_54[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 2, 2, 202)    0           concatenate_25[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 2, 2, 202)    808         concatenate_26[0][0]
# __________________________________________________________________________________________________
# re_lu_55 (ReLU)                 (None, 2, 2, 202)    0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 2, 2, 48)     9744        re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 2, 2, 48)     192         conv2d_56[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_56[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 2, 2, 214)    0           concatenate_26[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 2, 2, 214)    856         concatenate_27[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 2, 2, 214)    0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 2, 2, 48)     10320       re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 2, 2, 48)     192         conv2d_58[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_58[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 2, 2, 226)    0           concatenate_27[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 2, 2, 226)    904         concatenate_28[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, 2, 2, 226)    0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 2, 2, 48)     10896       re_lu_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 2, 2, 48)     192         conv2d_60[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_60[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 2, 2, 238)    0           concatenate_28[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 2, 2, 238)    952         concatenate_29[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, 2, 2, 238)    0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 2, 2, 48)     11472       re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 2, 2, 48)     192         conv2d_62[0][0]
# __________________________________________________________________________________________________
# re_lu_62 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 2, 2, 12)     5196        re_lu_62[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 2, 2, 250)    0           concatenate_29[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 2, 2, 250)    1000        concatenate_30[0][0]
# __________________________________________________________________________________________________
# re_lu_63 (ReLU)                 (None, 2, 2, 250)    0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 2, 2, 48)     12048       re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 2, 2, 48)     192         conv2d_64[0][0]
# __________________________________________________________________________________________________
# re_lu_64 (ReLU)                 (None, 2, 2, 48)     0           batch_normalization_64[0][0]
# ...
# conv2d_100 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_99[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 1, 1, 269)    0           concatenate_47[0][0]
#                                                                  conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 1, 1, 269)    1076        concatenate_48[0][0]
# __________________________________________________________________________________________________
# re_lu_100 (ReLU)                (None, 1, 1, 269)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 1, 1, 48)     12960       re_lu_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 1, 1, 48)     192         conv2d_101[0][0]
# __________________________________________________________________________________________________
# re_lu_101 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_101[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 1, 1, 281)    0           concatenate_48[0][0]
#                                                                  conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 1, 1, 281)    1124        concatenate_49[0][0]
# __________________________________________________________________________________________________
# re_lu_102 (ReLU)                (None, 1, 1, 281)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 1, 1, 48)     13536       re_lu_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 1, 1, 48)     192         conv2d_103[0][0]
# __________________________________________________________________________________________________
# re_lu_103 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_103[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 1, 1, 293)    0           concatenate_49[0][0]
#                                                                  conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 1, 1, 293)    1172        concatenate_50[0][0]
# __________________________________________________________________________________________________
# re_lu_104 (ReLU)                (None, 1, 1, 293)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 1, 1, 48)     14112       re_lu_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 1, 1, 48)     192         conv2d_105[0][0]
# __________________________________________________________________________________________________
# re_lu_105 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_105[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 1, 1, 305)    0           concatenate_50[0][0]
#                                                                  conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 1, 1, 305)    1220        concatenate_51[0][0]
# __________________________________________________________________________________________________
# re_lu_106 (ReLU)                (None, 1, 1, 305)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 1, 1, 48)     14688       re_lu_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 1, 1, 48)     192         conv2d_107[0][0]
# __________________________________________________________________________________________________
# re_lu_107 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_107[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 1, 1, 317)    0           concatenate_51[0][0]
#                                                                  conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 1, 1, 317)    1268        concatenate_52[0][0]
# __________________________________________________________________________________________________
# re_lu_108 (ReLU)                (None, 1, 1, 317)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 1, 1, 48)     15264       re_lu_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 1, 1, 48)     192         conv2d_109[0][0]
# __________________________________________________________________________________________________
# re_lu_109 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_109[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 1, 1, 329)    0           concatenate_52[0][0]
#                                                                  conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 1, 1, 329)    1316        concatenate_53[0][0]
# __________________________________________________________________________________________________
# re_lu_110 (ReLU)                (None, 1, 1, 329)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 1, 1, 48)     15840       re_lu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 1, 1, 48)     192         conv2d_111[0][0]
# __________________________________________________________________________________________________
# re_lu_111 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_111[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 1, 1, 341)    0           concatenate_53[0][0]
#                                                                  conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 1, 1, 341)    1364        concatenate_54[0][0]
# __________________________________________________________________________________________________
# re_lu_112 (ReLU)                (None, 1, 1, 341)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 1, 1, 48)     16416       re_lu_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 1, 1, 48)     192         conv2d_113[0][0]
# __________________________________________________________________________________________________
# re_lu_113 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_113[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 1, 1, 353)    0           concatenate_54[0][0]
#                                                                  conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 1, 1, 353)    1412        concatenate_55[0][0]
# __________________________________________________________________________________________________
# re_lu_114 (ReLU)                (None, 1, 1, 353)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 1, 1, 48)     16992       re_lu_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 1, 1, 48)     192         conv2d_115[0][0]
# __________________________________________________________________________________________________
# re_lu_115 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_115[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 1, 1, 365)    0           concatenate_55[0][0]
#                                                                  conv2d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 1, 1, 365)    1460        concatenate_56[0][0]
# __________________________________________________________________________________________________
# re_lu_116 (ReLU)                (None, 1, 1, 365)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 1, 1, 48)     17568       re_lu_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 1, 1, 48)     192         conv2d_117[0][0]
# __________________________________________________________________________________________________
# re_lu_117 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_117[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 1, 1, 377)    0           concatenate_56[0][0]
#                                                                  conv2d_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 1, 1, 377)    1508        concatenate_57[0][0]
# __________________________________________________________________________________________________
# re_lu_118 (ReLU)                (None, 1, 1, 377)    0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 1, 1, 48)     18144       re_lu_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 1, 1, 48)     192         conv2d_119[0][0]
# __________________________________________________________________________________________________
# re_lu_119 (ReLU)                (None, 1, 1, 48)     0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 1, 1, 12)     5196        re_lu_119[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 1, 1, 389)    0           concatenate_57[0][0]
#                                                                  conv2d_120[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 389)          0           concatenate_58[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 28)           10920       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 1,098,325
# Trainable params: 1,066,033
# Non-trainable params: 32,292
# __________________________________________________________________________________________________
# CPU times: user 7.82 s, sys: 525 ms, total: 8.35 s
# Wall time: 9.35 s

# %%
# %%time
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
# ep = 50
# bs = 16
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('DenseNet')
    filename = '/content/drive/My Drive/Notebook/Training_Files/DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 65s 56ms/step - loss: 2.4880 - accuracy: 0.2782 - val_loss: 3.3342 - val_accuracy: 0.0893
# Epoch 2/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 1.0354 - accuracy: 0.6925 - val_loss: 4.2263 - val_accuracy: 0.0722
# Epoch 3/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.5998 - accuracy: 0.8165 - val_loss: 5.4621 - val_accuracy: 0.0515
# Epoch 4/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.4475 - accuracy: 0.8562 - val_loss: 4.5426 - val_accuracy: 0.1856
# Epoch 5/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.3054 - accuracy: 0.9070 - val_loss: 4.6252 - val_accuracy: 0.2474
# Epoch 6/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.2642 - accuracy: 0.9147 - val_loss: 1.7667 - val_accuracy: 0.5292
# Epoch 7/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.2338 - accuracy: 0.9276 - val_loss: 1.3856 - val_accuracy: 0.6186
# Epoch 8/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.2587 - accuracy: 0.9225 - val_loss: 1.4957 - val_accuracy: 0.6186
# Epoch 9/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1431 - accuracy: 0.9561 - val_loss: 4.1435 - val_accuracy: 0.3849
# Epoch 10/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0963 - accuracy: 0.9681 - val_loss: 3.7839 - val_accuracy: 0.4261
# Epoch 11/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0821 - accuracy: 0.9811 - val_loss: 1.1120 - val_accuracy: 0.7079
# Epoch 12/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1025 - accuracy: 0.9724 - val_loss: 0.9981 - val_accuracy: 0.7285
# Epoch 13/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0995 - accuracy: 0.9673 - val_loss: 0.8981 - val_accuracy: 0.7732
# Epoch 14/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1188 - accuracy: 0.9664 - val_loss: 1.9758 - val_accuracy: 0.5430
# Epoch 15/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0882 - accuracy: 0.9673 - val_loss: 0.8349 - val_accuracy: 0.7973
# Epoch 16/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0961 - accuracy: 0.9716 - val_loss: 1.7483 - val_accuracy: 0.6632
# Epoch 17/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.2056 - accuracy: 0.9440 - val_loss: 1.9773 - val_accuracy: 0.6323
# Epoch 18/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1162 - accuracy: 0.9630 - val_loss: 0.8319 - val_accuracy: 0.8007
# Epoch 19/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0921 - accuracy: 0.9716 - val_loss: 1.6853 - val_accuracy: 0.6838
# Epoch 20/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1187 - accuracy: 0.9707 - val_loss: 1.5181 - val_accuracy: 0.6632
# Epoch 21/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0569 - accuracy: 0.9836 - val_loss: 0.6367 - val_accuracy: 0.8522
# Epoch 22/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0318 - accuracy: 0.9897 - val_loss: 1.3618 - val_accuracy: 0.7595
# Epoch 23/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0620 - accuracy: 0.9776 - val_loss: 1.0692 - val_accuracy: 0.7560
# Epoch 24/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0541 - accuracy: 0.9854 - val_loss: 1.0064 - val_accuracy: 0.7904
# Epoch 25/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0238 - accuracy: 0.9914 - val_loss: 0.8475 - val_accuracy: 0.8316
# Epoch 26/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0710 - accuracy: 0.9793 - val_loss: 0.6643 - val_accuracy: 0.8454
# Epoch 27/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0785 - accuracy: 0.9699 - val_loss: 1.0190 - val_accuracy: 0.7973
# Epoch 28/50
# 1161/1161 [==============================] - 15s 12ms/step - loss: 0.1254 - accuracy: 0.9612 - val_loss: 0.9824 - val_accuracy: 0.7973
# Epoch 29/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0888 - accuracy: 0.9733 - val_loss: 2.0290 - val_accuracy: 0.6151
# Epoch 30/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1504 - accuracy: 0.9543 - val_loss: 2.5880 - val_accuracy: 0.5739
# Epoch 31/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1399 - accuracy: 0.9569 - val_loss: 1.4123 - val_accuracy: 0.7457
# Epoch 32/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0513 - accuracy: 0.9802 - val_loss: 1.8938 - val_accuracy: 0.6907
# Epoch 33/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0152 - accuracy: 0.9948 - val_loss: 0.4707 - val_accuracy: 0.8866
# Epoch 34/50
# 1161/1161 [==============================] - 15s 12ms/step - loss: 0.0137 - accuracy: 0.9966 - val_loss: 0.3597 - val_accuracy: 0.9038
# Epoch 35/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.4932 - val_accuracy: 0.9003
# Epoch 36/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0395 - accuracy: 0.9888 - val_loss: 0.5098 - val_accuracy: 0.8729
# Epoch 37/50
# 1161/1161 [==============================] - 15s 12ms/step - loss: 0.0551 - accuracy: 0.9845 - val_loss: 0.6255 - val_accuracy: 0.8832
# Epoch 38/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0308 - accuracy: 0.9914 - val_loss: 0.3348 - val_accuracy: 0.9210
# Epoch 39/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.3544 - val_accuracy: 0.9175
# Epoch 40/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.3697 - val_accuracy: 0.9003
# Epoch 41/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0670 - accuracy: 0.9871 - val_loss: 1.7462 - val_accuracy: 0.7732
# Epoch 42/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.2000 - accuracy: 0.9543 - val_loss: 1.1505 - val_accuracy: 0.7766
# Epoch 43/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1610 - accuracy: 0.9535 - val_loss: 0.8681 - val_accuracy: 0.8282
# Epoch 44/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1486 - accuracy: 0.9621 - val_loss: 1.6224 - val_accuracy: 0.7010
# Epoch 45/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.1090 - accuracy: 0.9699 - val_loss: 0.6965 - val_accuracy: 0.8832
# Epoch 46/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0716 - accuracy: 0.9828 - val_loss: 0.7925 - val_accuracy: 0.8351
# Epoch 47/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0513 - accuracy: 0.9845 - val_loss: 1.3735 - val_accuracy: 0.8076
# Epoch 48/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0610 - accuracy: 0.9811 - val_loss: 0.5148 - val_accuracy: 0.8935
# Epoch 49/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.3353 - val_accuracy: 0.9278
# Epoch 50/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 0.0219 - accuracy: 0.9957 - val_loss: 0.3854 - val_accuracy: 0.9278
# 291/291 [==============================] - 0s 1ms/step
# accuracy: 92.78%
# k =  1
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 72s 62ms/step - loss: 0.1777 - accuracy: 0.9518 - val_loss: 0.1938 - val_accuracy: 0.9553
# Epoch 2/50
# 1161/1161 [==============================] - 16s 13ms/step - loss: 0.1276 - accuracy: 0.9647 - val_loss: 0.0532 - val_accuracy: 0.9863
# Epoch 3/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0901 - accuracy: 0.9733 - val_loss: 1.6643 - val_accuracy: 0.7010
# Epoch 4/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0898 - accuracy: 0.9742 - val_loss: 0.1254 - val_accuracy: 0.9656
# Epoch 5/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0546 - accuracy: 0.9845 - val_loss: 0.1042 - val_accuracy: 0.9691
# Epoch 6/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0621 - accuracy: 0.9862 - val_loss: 0.4195 - val_accuracy: 0.8969
# Epoch 7/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0652 - accuracy: 0.9854 - val_loss: 0.3083 - val_accuracy: 0.9175
# Epoch 8/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0269 - accuracy: 0.9948 - val_loss: 0.0289 - val_accuracy: 0.9897
# Epoch 9/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0322 - accuracy: 0.9922 - val_loss: 0.2696 - val_accuracy: 0.9519
# Epoch 10/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0649 - accuracy: 0.9862 - val_loss: 0.3145 - val_accuracy: 0.9278
# Epoch 11/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0462 - accuracy: 0.9845 - val_loss: 0.2108 - val_accuracy: 0.9519
# Epoch 12/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0245 - accuracy: 0.9922 - val_loss: 0.1041 - val_accuracy: 0.9725
# Epoch 13/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0319 - accuracy: 0.9905 - val_loss: 0.1355 - val_accuracy: 0.9656
# Epoch 14/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0313 - accuracy: 0.9897 - val_loss: 0.0452 - val_accuracy: 0.9897
# Epoch 15/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0580 - accuracy: 0.9828 - val_loss: 1.4172 - val_accuracy: 0.8247
# Epoch 16/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0548 - accuracy: 0.9802 - val_loss: 0.2104 - val_accuracy: 0.9313
# Epoch 17/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0600 - accuracy: 0.9819 - val_loss: 0.5894 - val_accuracy: 0.8625
# Epoch 18/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0674 - accuracy: 0.9819 - val_loss: 0.6527 - val_accuracy: 0.8694
# Epoch 19/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0947 - accuracy: 0.9750 - val_loss: 0.2442 - val_accuracy: 0.9347
# Epoch 20/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.1221 - accuracy: 0.9638 - val_loss: 0.4937 - val_accuracy: 0.9003
# Epoch 21/50
# 1161/1161 [==============================] - 16s 13ms/step - loss: 0.1067 - accuracy: 0.9716 - val_loss: 0.6189 - val_accuracy: 0.8694
# Epoch 22/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0341 - accuracy: 0.9905 - val_loss: 0.1625 - val_accuracy: 0.9588
# Epoch 23/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0331 - accuracy: 0.9897 - val_loss: 0.0739 - val_accuracy: 0.9828
# Epoch 24/50
# 1161/1161 [==============================] - 16s 13ms/step - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.0815 - val_accuracy: 0.9828
# Epoch 25/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.0694 - val_accuracy: 0.9863
# Epoch 26/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 0.9863
# Epoch 27/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 0.9863
# Epoch 28/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.1191 - val_accuracy: 0.9828
# Epoch 29/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 6.6635e-04 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9828
# Epoch 30/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9828
# Epoch 31/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 9.9314e-04 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 0.9828
# Epoch 32/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 4.0681e-04 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 0.9828
# Epoch 33/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 2.9038e-04 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 0.9828
# Epoch 34/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.7357e-04 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 0.9828
# Epoch 35/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.1761e-04 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9828
# Epoch 36/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.4995e-04 - accuracy: 1.0000 - val_loss: 0.0863 - val_accuracy: 0.9828
# Epoch 37/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 1.6721e-04 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 0.9828
# Epoch 38/50
# 1161/1161 [==============================] - 14s 12ms/step - loss: 2.2962e-04 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 0.9828
# Epoch 39/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 2.8892e-04 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 0.9828
# Epoch 40/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 3.3274e-04 - accuracy: 1.0000 - val_loss: 0.1005 - val_accuracy: 0.9828
# Epoch 41/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 3.2560e-04 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9828
# Epoch 42/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.3723e-04 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 0.9828
# Epoch 43/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 3.7713e-04 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9828
# Epoch 44/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.5407e-04 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 0.9828
# Epoch 45/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.2229e-04 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 0.9828
# Epoch 46/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 6.0777e-05 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 0.9828
# Epoch 47/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.1780e-04 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 0.9828
# Epoch 48/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 2.9656e-04 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 0.9828
# Epoch 49/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 4.8561e-04 - accuracy: 1.0000 - val_loss: 0.0887 - val_accuracy: 0.9828
# Epoch 50/50
# 1161/1161 [==============================] - 15s 13ms/step - loss: 1.4891e-04 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9828
# 291/291 [==============================] - 0s 973us/step
# accuracy: 98.28%
# k =  2
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 70s 60ms/step - loss: 0.0772 - accuracy: 0.9828 - val_loss: 0.2646 - val_accuracy: 0.9172
# Epoch 2/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0386 - accuracy: 0.9854 - val_loss: 0.0720 - val_accuracy: 0.9828
# Epoch 3/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0401 - accuracy: 0.9871 - val_loss: 1.0276 - val_accuracy: 0.8138
# Epoch 4/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0553 - accuracy: 0.9854 - val_loss: 0.2505 - val_accuracy: 0.9448
# Epoch 5/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.1040 - accuracy: 0.9716 - val_loss: 0.7078 - val_accuracy: 0.8483
# Epoch 6/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0796 - accuracy: 0.9776 - val_loss: 5.3899 - val_accuracy: 0.4931
# Epoch 7/50
# 1162/1162 [==============================] - 15s 13ms/step - loss: 0.0581 - accuracy: 0.9819 - val_loss: 0.1043 - val_accuracy: 0.9621
# Epoch 8/50
# 1162/1162 [==============================] - 15s 13ms/step - loss: 0.0544 - accuracy: 0.9905 - val_loss: 0.1849 - val_accuracy: 0.9724
# Epoch 9/50
# 1162/1162 [==============================] - 15s 13ms/step - loss: 0.0533 - accuracy: 0.9845 - val_loss: 0.0291 - val_accuracy: 0.9897
# Epoch 10/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0164 - accuracy: 0.9931 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 11/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 6.7887e-04 - val_accuracy: 1.0000
# Epoch 12/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0145 - val_accuracy: 0.9966
# Epoch 13/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0348 - accuracy: 0.9871 - val_loss: 0.1740 - val_accuracy: 0.9586
# Epoch 14/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0248 - accuracy: 0.9931 - val_loss: 0.0099 - val_accuracy: 0.9966
# Epoch 15/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0465 - accuracy: 0.9923 - val_loss: 0.0427 - val_accuracy: 0.9862
# Epoch 16/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0434 - accuracy: 0.9923 - val_loss: 0.0834 - val_accuracy: 0.9759
# Epoch 17/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.0077 - val_accuracy: 0.9966
# Epoch 18/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 0.0073 - val_accuracy: 0.9966
# Epoch 19/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0063 - accuracy: 0.9974 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 20/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0252 - val_accuracy: 0.9897
# Epoch 21/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0052 - val_accuracy: 0.9966
# Epoch 22/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0373 - accuracy: 0.9897 - val_loss: 0.2956 - val_accuracy: 0.9241
# Epoch 23/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0968 - accuracy: 0.9759 - val_loss: 0.3840 - val_accuracy: 0.9172
# Epoch 24/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.1855 - accuracy: 0.9578 - val_loss: 2.2552 - val_accuracy: 0.7276
# Epoch 25/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0620 - accuracy: 0.9871 - val_loss: 1.0050 - val_accuracy: 0.8655
# Epoch 26/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9828
# Epoch 27/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9966
# Epoch 28/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0278 - accuracy: 0.9948 - val_loss: 0.0284 - val_accuracy: 0.9862
# Epoch 29/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 0.0579 - val_accuracy: 0.9897
# Epoch 30/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0211 - val_accuracy: 0.9966
# Epoch 31/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0271 - accuracy: 0.9957 - val_loss: 1.0256 - val_accuracy: 0.8621
# Epoch 32/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0615 - accuracy: 0.9862 - val_loss: 0.5007 - val_accuracy: 0.8793
# Epoch 33/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0410 - accuracy: 0.9897 - val_loss: 0.6348 - val_accuracy: 0.8724
# Epoch 34/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0358 - accuracy: 0.9897 - val_loss: 0.2231 - val_accuracy: 0.9483
# Epoch 35/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0324 - accuracy: 0.9888 - val_loss: 0.0672 - val_accuracy: 0.9862
# Epoch 36/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0646 - accuracy: 0.9836 - val_loss: 0.9167 - val_accuracy: 0.8103
# Epoch 37/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0214 - accuracy: 0.9940 - val_loss: 0.0274 - val_accuracy: 0.9931
# Epoch 38/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0511 - val_accuracy: 0.9793
# Epoch 39/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.0598 - val_accuracy: 0.9828
# Epoch 40/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0205 - val_accuracy: 0.9828
# Epoch 41/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 0.0452 - val_accuracy: 0.9862
# Epoch 42/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0398 - accuracy: 0.9914 - val_loss: 0.0553 - val_accuracy: 0.9759
# Epoch 43/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0461 - accuracy: 0.9845 - val_loss: 0.2473 - val_accuracy: 0.9345
# Epoch 44/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0230 - accuracy: 0.9905 - val_loss: 1.2620 - val_accuracy: 0.8379
# Epoch 45/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.1415 - val_accuracy: 0.9724
# Epoch 46/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0404 - accuracy: 0.9914 - val_loss: 0.1769 - val_accuracy: 0.9586
# Epoch 47/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0567 - accuracy: 0.9862 - val_loss: 0.0697 - val_accuracy: 0.9828
# Epoch 48/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0541 - val_accuracy: 0.9862
# Epoch 49/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0039 - accuracy: 0.9983 - val_loss: 0.0194 - val_accuracy: 0.9897
# Epoch 50/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0064 - accuracy: 0.9974 - val_loss: 0.0102 - val_accuracy: 0.9966
# 290/290 [==============================] - 0s 966us/step
# accuracy: 99.66%
# k =  3
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 67s 57ms/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 0.2804 - val_accuracy: 0.9241
# Epoch 2/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0346 - accuracy: 0.9905 - val_loss: 0.0385 - val_accuracy: 0.9931
# Epoch 3/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0474 - accuracy: 0.9828 - val_loss: 0.0322 - val_accuracy: 0.9931
# Epoch 4/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0235 - accuracy: 0.9931 - val_loss: 0.0176 - val_accuracy: 0.9966
# Epoch 5/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 6.6937e-04 - val_accuracy: 1.0000
# Epoch 6/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 5.0612e-04 - accuracy: 1.0000 - val_loss: 2.2694e-04 - val_accuracy: 1.0000
# Epoch 7/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 4.0680e-04 - val_accuracy: 1.0000
# Epoch 8/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 8.9886e-04 - accuracy: 1.0000 - val_loss: 3.5465e-04 - val_accuracy: 1.0000
# Epoch 9/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 10/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0304 - accuracy: 0.9923 - val_loss: 0.0081 - val_accuracy: 0.9966
# Epoch 11/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.1114 - accuracy: 0.9733 - val_loss: 15.9889 - val_accuracy: 0.5069
# Epoch 12/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.1734 - accuracy: 0.9690 - val_loss: 0.5581 - val_accuracy: 0.9103
# Epoch 13/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0624 - accuracy: 0.9819 - val_loss: 0.0798 - val_accuracy: 0.9862
# Epoch 14/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0135 - val_accuracy: 0.9966
# Epoch 15/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0075 - accuracy: 0.9966 - val_loss: 5.9412e-04 - val_accuracy: 1.0000
# Epoch 16/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0325 - accuracy: 0.9948 - val_loss: 0.0231 - val_accuracy: 0.9931
# Epoch 17/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9966
# Epoch 18/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0246 - accuracy: 0.9957 - val_loss: 0.0408 - val_accuracy: 0.9862
# Epoch 19/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0416 - accuracy: 0.9923 - val_loss: 0.2171 - val_accuracy: 0.9517
# Epoch 20/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0336 - accuracy: 0.9905 - val_loss: 0.0418 - val_accuracy: 0.9897
# Epoch 21/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0826 - accuracy: 0.9862 - val_loss: 1.6773 - val_accuracy: 0.8000
# Epoch 22/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0237 - accuracy: 0.9923 - val_loss: 0.0697 - val_accuracy: 0.9828
# Epoch 23/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0107 - accuracy: 0.9983 - val_loss: 0.0272 - val_accuracy: 0.9897
# Epoch 24/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0293 - accuracy: 0.9948 - val_loss: 0.0178 - val_accuracy: 0.9897
# Epoch 25/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0480 - accuracy: 0.9880 - val_loss: 0.0123 - val_accuracy: 0.9966
# Epoch 26/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0129 - accuracy: 0.9948 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 27/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0042 - accuracy: 0.9983 - val_loss: 0.0078 - val_accuracy: 0.9966
# Epoch 28/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 5.6408e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9966
# Epoch 29/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 7.4157e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 30/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0013 - accuracy: 0.9991 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 31/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 5.2681e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 32/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 3.7078e-04 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 33/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 6.0340e-04 - accuracy: 1.0000 - val_loss: 5.7546e-04 - val_accuracy: 1.0000
# Epoch 34/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 8.6920e-04 - accuracy: 0.9991 - val_loss: 3.5867e-04 - val_accuracy: 1.0000
# Epoch 35/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 3.6653e-04 - accuracy: 1.0000 - val_loss: 3.4700e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 1.6258e-04 - accuracy: 1.0000 - val_loss: 3.6326e-04 - val_accuracy: 1.0000
# Epoch 37/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 7.2295e-05 - accuracy: 1.0000 - val_loss: 4.5416e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 7.3596e-05 - accuracy: 1.0000 - val_loss: 3.2292e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 6.7790e-05 - accuracy: 1.0000 - val_loss: 3.0977e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 2.7322e-04 - accuracy: 1.0000 - val_loss: 3.0882e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 1.2368e-04 - accuracy: 1.0000 - val_loss: 3.8575e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 6.3909e-05 - accuracy: 1.0000 - val_loss: 8.5717e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 1.0060e-04 - accuracy: 1.0000 - val_loss: 9.0124e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 9.0671e-05 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 45/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 5.0518e-04 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9966
# Epoch 46/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0849 - accuracy: 0.9819 - val_loss: 1.8435 - val_accuracy: 0.7966
# Epoch 47/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.1687 - accuracy: 0.9561 - val_loss: 5.5688 - val_accuracy: 0.5552
# Epoch 48/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.2196 - accuracy: 0.9544 - val_loss: 0.6830 - val_accuracy: 0.8759
# Epoch 49/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0866 - accuracy: 0.9733 - val_loss: 0.5747 - val_accuracy: 0.9103
# Epoch 50/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0471 - accuracy: 0.9854 - val_loss: 0.2211 - val_accuracy: 0.9448
# 290/290 [==============================] - 0s 948us/step
# accuracy: 94.48%
# k =  4
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 68s 58ms/step - loss: 0.0369 - accuracy: 0.9888 - val_loss: 0.0108 - val_accuracy: 0.9966
# Epoch 2/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0098 - accuracy: 0.9948 - val_loss: 0.0107 - val_accuracy: 0.9966
# Epoch 3/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0232 - accuracy: 0.9914 - val_loss: 0.0448 - val_accuracy: 0.9897
# Epoch 4/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.1138 - val_accuracy: 0.9862
# Epoch 5/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0227 - accuracy: 0.9914 - val_loss: 0.1139 - val_accuracy: 0.9897
# Epoch 6/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 0.0374 - val_accuracy: 0.9897
# Epoch 7/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0060 - accuracy: 0.9991 - val_loss: 4.8338e-04 - val_accuracy: 1.0000
# Epoch 8/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0304 - accuracy: 0.9880 - val_loss: 0.2493 - val_accuracy: 0.9724
# Epoch 9/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0552 - accuracy: 0.9854 - val_loss: 0.0962 - val_accuracy: 0.9897
# Epoch 10/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0355 - accuracy: 0.9897 - val_loss: 0.0468 - val_accuracy: 0.9897
# Epoch 11/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0242 - accuracy: 0.9940 - val_loss: 0.0218 - val_accuracy: 0.9931
# Epoch 12/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0279 - accuracy: 0.9940 - val_loss: 0.0293 - val_accuracy: 0.9966
# Epoch 13/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0388 - accuracy: 0.9940 - val_loss: 0.0974 - val_accuracy: 0.9897
# Epoch 14/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0433 - accuracy: 0.9897 - val_loss: 0.1110 - val_accuracy: 0.9828
# Epoch 15/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 0.0318 - val_accuracy: 0.9897
# Epoch 16/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 7.2181e-04 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 0.9966
# Epoch 17/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0013 - accuracy: 0.9991 - val_loss: 0.0085 - val_accuracy: 0.9966
# Epoch 18/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 4.5086e-04 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 0.9966
# Epoch 19/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 5.4462e-04 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 0.9966
# Epoch 20/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9966
# Epoch 21/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.0241 - val_accuracy: 0.9966
# Epoch 22/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0239 - accuracy: 0.9948 - val_loss: 0.0456 - val_accuracy: 0.9862
# Epoch 23/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0176 - accuracy: 0.9957 - val_loss: 0.0355 - val_accuracy: 0.9862
# Epoch 24/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0077 - accuracy: 0.9983 - val_loss: 0.0204 - val_accuracy: 0.9897
# Epoch 25/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0180 - val_accuracy: 0.9966
# Epoch 26/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0744 - accuracy: 0.9940 - val_loss: 0.2220 - val_accuracy: 0.9552
# Epoch 27/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0152 - val_accuracy: 0.9931
# Epoch 28/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0446 - accuracy: 0.9931 - val_loss: 0.8470 - val_accuracy: 0.8724
# Epoch 29/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0942 - accuracy: 0.9888 - val_loss: 0.4795 - val_accuracy: 0.9379
# Epoch 30/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0134 - accuracy: 0.9948 - val_loss: 0.1415 - val_accuracy: 0.9655
# Epoch 31/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0329 - accuracy: 0.9940 - val_loss: 0.1523 - val_accuracy: 0.9793
# Epoch 32/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0282 - accuracy: 0.9931 - val_loss: 0.0936 - val_accuracy: 0.9793
# Epoch 33/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0598 - accuracy: 0.9845 - val_loss: 0.0676 - val_accuracy: 0.9828
# Epoch 34/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.0516 - val_accuracy: 0.9862
# Epoch 35/50
# 1162/1162 [==============================] - 13s 11ms/step - loss: 0.0204 - accuracy: 0.9940 - val_loss: 0.0264 - val_accuracy: 0.9897
# Epoch 36/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0323 - accuracy: 0.9940 - val_loss: 0.0445 - val_accuracy: 0.9897
# Epoch 37/50
# 1162/1162 [==============================] - 13s 12ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0458 - val_accuracy: 0.9931
# Epoch 38/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0189 - accuracy: 0.9957 - val_loss: 0.0627 - val_accuracy: 0.9931
# Epoch 39/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.1403 - val_accuracy: 0.9655
# Epoch 40/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0782 - accuracy: 0.9811 - val_loss: 0.0394 - val_accuracy: 0.9897
# Epoch 41/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0460 - accuracy: 0.9931 - val_loss: 0.0331 - val_accuracy: 0.9931
# Epoch 42/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0119 - accuracy: 0.9948 - val_loss: 0.0822 - val_accuracy: 0.9931
# Epoch 43/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0191 - accuracy: 0.9948 - val_loss: 0.1056 - val_accuracy: 0.9828
# Epoch 44/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0253 - accuracy: 0.9923 - val_loss: 0.1509 - val_accuracy: 0.9724
# Epoch 45/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.1259 - val_accuracy: 0.9724
# Epoch 46/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0115 - accuracy: 0.9974 - val_loss: 0.1388 - val_accuracy: 0.9724
# Epoch 47/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0542 - val_accuracy: 0.9897
# Epoch 48/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 6.2884e-04 - accuracy: 1.0000 - val_loss: 0.0536 - val_accuracy: 0.9862
# Epoch 49/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 6.5760e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 0.9966
# Epoch 50/50
# 1162/1162 [==============================] - 14s 12ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9966
# 290/290 [==============================] - 0s 1ms/step
# accuracy: 99.66%
# 96.97% (+/- 2.82%)
# CPU times: user 1h 23min 50s, sys: 5min 1s, total: 1h 28min 51s
# Wall time: 1h 8min 55s

# %% [markdown]
# ### **Result**

# %%
# summarize history for accuracy
filename = '/content/drive/My Drive/Notebook/Training_Files/history_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.93      0.97        15
#            2       0.93      1.00      0.96        25
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        23
#            5       0.88      0.88      0.88        24
#            6       1.00      0.81      0.89        21
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         8
#           12       1.00      1.00      1.00        16
#           13       0.85      1.00      0.92        11
#           14       1.00      0.91      0.95        11
#           15       1.00      1.00      1.00        11
#           16       1.00      1.00      1.00         5
#           17       0.92      0.92      0.92        12
#           18       0.83      1.00      0.91        10
#           19       1.00      1.00      1.00        10
#           20       1.00      1.00      1.00        11
#           21       0.85      0.92      0.88        12
#           22       0.90      1.00      0.95        18
#           23       0.85      0.92      0.88        24
#           24       1.00      0.88      0.94        17
#           25       1.00      1.00      1.00         3
#           26       1.00      0.78      0.88         9
#           27       1.00      0.96      0.98        28
#
#     accuracy                           0.95       363
#    macro avg       0.96      0.96      0.96       363
# weighted avg       0.95      0.95      0.95       363

# %% [markdown]
# ### **Next DK**

# %%
# %reset_selective -f data_train
# %reset_selective -f data_test
# %reset_selective -f y_train
# %reset_selective -f y_test
# %reset_selective -f loaded_train
# %reset_selective -f loaded_test
# %reset_selective -f model
sns.reset_orig()

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42
dtype = 'DK'
data_train, data_test, y_train, y_test = train_test_split(
data_dk, label_dk, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %%
# %%time
K.clear_session()
model = densenet(input_shape, n_classes, f=f)
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('DenseNet')
    filename = '/content/drive/My Drive/Notebook/Training_Files/DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 81s 70ms/step - loss: 2.5049 - accuracy: 0.2748 - val_loss: 3.3143 - val_accuracy: 0.0619
# Epoch 2/50
# 1161/1161 [==============================] - 17s 15ms/step - loss: 1.1549 - accuracy: 0.6477 - val_loss: 3.8355 - val_accuracy: 0.0515
# Epoch 3/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.6200 - accuracy: 0.8071 - val_loss: 3.8869 - val_accuracy: 0.0481
# Epoch 4/50
# 1161/1161 [==============================] - 18s 16ms/step - loss: 0.4329 - accuracy: 0.8674 - val_loss: 3.8407 - val_accuracy: 0.2062
# Epoch 5/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.3354 - accuracy: 0.9018 - val_loss: 3.6543 - val_accuracy: 0.2302
# Epoch 6/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2854 - accuracy: 0.9078 - val_loss: 2.6342 - val_accuracy: 0.3540
# Epoch 7/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2677 - accuracy: 0.9078 - val_loss: 1.6461 - val_accuracy: 0.5876
# Epoch 8/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2485 - accuracy: 0.9268 - val_loss: 2.0486 - val_accuracy: 0.5601
# Epoch 9/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1849 - accuracy: 0.9406 - val_loss: 2.3075 - val_accuracy: 0.5189
# Epoch 10/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1559 - accuracy: 0.9543 - val_loss: 1.4775 - val_accuracy: 0.6460
# Epoch 11/50
# 1161/1161 [==============================] - 20s 18ms/step - loss: 0.1069 - accuracy: 0.9699 - val_loss: 4.8737 - val_accuracy: 0.3299
# Epoch 12/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0996 - accuracy: 0.9681 - val_loss: 2.6484 - val_accuracy: 0.5052
# Epoch 13/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1497 - accuracy: 0.9509 - val_loss: 0.7870 - val_accuracy: 0.7698
# Epoch 14/50
# 1161/1161 [==============================] - 18s 16ms/step - loss: 0.1466 - accuracy: 0.9526 - val_loss: 0.9046 - val_accuracy: 0.8213
# Epoch 15/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1112 - accuracy: 0.9630 - val_loss: 2.2093 - val_accuracy: 0.5911
# Epoch 16/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0550 - accuracy: 0.9802 - val_loss: 2.1676 - val_accuracy: 0.5739
# Epoch 17/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0644 - accuracy: 0.9759 - val_loss: 4.0915 - val_accuracy: 0.4433
# Epoch 18/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0437 - accuracy: 0.9871 - val_loss: 0.4163 - val_accuracy: 0.9072
# Epoch 19/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0575 - accuracy: 0.9862 - val_loss: 2.4196 - val_accuracy: 0.5395
# Epoch 20/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0875 - accuracy: 0.9759 - val_loss: 3.2963 - val_accuracy: 0.5326
# Epoch 21/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0842 - accuracy: 0.9759 - val_loss: 1.1354 - val_accuracy: 0.7595
# Epoch 22/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1702 - accuracy: 0.9509 - val_loss: 5.0063 - val_accuracy: 0.4227
# Epoch 23/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1602 - accuracy: 0.9483 - val_loss: 1.3816 - val_accuracy: 0.7010
# Epoch 24/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0714 - accuracy: 0.9785 - val_loss: 0.6708 - val_accuracy: 0.8316
# Epoch 25/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0133 - accuracy: 0.9983 - val_loss: 0.4215 - val_accuracy: 0.9175
# Epoch 26/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0180 - accuracy: 0.9957 - val_loss: 0.3505 - val_accuracy: 0.9313
# Epoch 27/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0245 - accuracy: 0.9974 - val_loss: 0.6982 - val_accuracy: 0.8660
# Epoch 28/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0312 - accuracy: 0.9922 - val_loss: 0.5477 - val_accuracy: 0.8763
# Epoch 29/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0151 - accuracy: 0.9966 - val_loss: 0.3384 - val_accuracy: 0.9107
# Epoch 30/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0320 - accuracy: 0.9888 - val_loss: 7.4642 - val_accuracy: 0.3058
# Epoch 31/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0711 - accuracy: 0.9828 - val_loss: 2.7133 - val_accuracy: 0.5979
# Epoch 32/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1683 - accuracy: 0.9543 - val_loss: 3.7396 - val_accuracy: 0.4536
# Epoch 33/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1204 - accuracy: 0.9621 - val_loss: 5.7364 - val_accuracy: 0.4296
# Epoch 34/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1530 - accuracy: 0.9587 - val_loss: 4.3100 - val_accuracy: 0.5086
# Epoch 35/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1527 - accuracy: 0.9578 - val_loss: 5.8474 - val_accuracy: 0.3986
# Epoch 36/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1129 - accuracy: 0.9767 - val_loss: 1.5105 - val_accuracy: 0.6873
# Epoch 37/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0939 - accuracy: 0.9707 - val_loss: 1.2102 - val_accuracy: 0.7595
# Epoch 38/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0593 - accuracy: 0.9811 - val_loss: 1.8910 - val_accuracy: 0.6667
# Epoch 39/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0360 - accuracy: 0.9879 - val_loss: 1.1820 - val_accuracy: 0.7732
# Epoch 40/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0986 - accuracy: 0.9742 - val_loss: 2.5920 - val_accuracy: 0.5808
# Epoch 41/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0756 - accuracy: 0.9802 - val_loss: 0.8378 - val_accuracy: 0.7973
# Epoch 42/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.2701 - val_accuracy: 0.9244
# Epoch 43/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0212 - accuracy: 0.9914 - val_loss: 0.3604 - val_accuracy: 0.9175
# Epoch 44/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0354 - accuracy: 0.9905 - val_loss: 0.3847 - val_accuracy: 0.9313
# Epoch 45/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0114 - accuracy: 0.9957 - val_loss: 0.2549 - val_accuracy: 0.9553
# Epoch 46/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 0.2781 - val_accuracy: 0.9416
# Epoch 47/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.2612 - val_accuracy: 0.9485
# Epoch 48/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0058 - accuracy: 0.9974 - val_loss: 0.2488 - val_accuracy: 0.9416
# Epoch 49/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.2530 - val_accuracy: 0.9450
# Epoch 50/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2147 - val_accuracy: 0.9485
# 291/291 [==============================] - 1s 4ms/step
# accuracy: 94.85%
# k =  1
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 80s 69ms/step - loss: 0.2109 - accuracy: 0.9535 - val_loss: 1.3255 - val_accuracy: 0.7595
# Epoch 2/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1348 - accuracy: 0.9681 - val_loss: 2.4800 - val_accuracy: 0.6976
# Epoch 3/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0907 - accuracy: 0.9759 - val_loss: 0.5538 - val_accuracy: 0.8625
# Epoch 4/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0864 - accuracy: 0.9767 - val_loss: 1.8811 - val_accuracy: 0.6598
# Epoch 5/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0690 - accuracy: 0.9854 - val_loss: 0.1289 - val_accuracy: 0.9656
# Epoch 6/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.0218 - val_accuracy: 0.9931
# Epoch 7/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0355 - val_accuracy: 0.9897
# Epoch 8/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 9/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 10/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 9.5028e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 11/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.0133 - val_accuracy: 0.9966
# Epoch 12/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0660 - accuracy: 0.9862 - val_loss: 2.7022 - val_accuracy: 0.6254
# Epoch 13/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1565 - accuracy: 0.9518 - val_loss: 6.6684 - val_accuracy: 0.3608
# Epoch 14/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2243 - accuracy: 0.9414 - val_loss: 23.0933 - val_accuracy: 0.1031
# Epoch 15/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2238 - accuracy: 0.9457 - val_loss: 2.5875 - val_accuracy: 0.6117
# Epoch 16/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1838 - accuracy: 0.9457 - val_loss: 1.0639 - val_accuracy: 0.7973
# Epoch 17/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0478 - accuracy: 0.9862 - val_loss: 0.1361 - val_accuracy: 0.9794
# Epoch 18/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9828
# Epoch 19/50
# 1161/1161 [==============================] - 20s 18ms/step - loss: 0.0256 - accuracy: 0.9931 - val_loss: 0.1494 - val_accuracy: 0.9485
# Epoch 20/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0131 - accuracy: 0.9957 - val_loss: 0.1253 - val_accuracy: 0.9588
# Epoch 21/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0220 - accuracy: 0.9948 - val_loss: 0.4986 - val_accuracy: 0.8694
# Epoch 22/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0099 - accuracy: 0.9966 - val_loss: 0.0949 - val_accuracy: 0.9759
# Epoch 23/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0040 - accuracy: 0.9983 - val_loss: 0.0895 - val_accuracy: 0.9828
# Epoch 24/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 9.2568e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9828
# Epoch 25/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0278 - accuracy: 0.9966 - val_loss: 0.1233 - val_accuracy: 0.9725
# Epoch 26/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.1996 - val_accuracy: 0.9553
# Epoch 27/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0961 - val_accuracy: 0.9794
# Epoch 28/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0477 - accuracy: 0.9914 - val_loss: 0.6230 - val_accuracy: 0.8282
# Epoch 29/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0213 - accuracy: 0.9940 - val_loss: 0.2256 - val_accuracy: 0.9416
# Epoch 30/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0184 - accuracy: 0.9948 - val_loss: 0.0912 - val_accuracy: 0.9725
# Epoch 31/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0199 - accuracy: 0.9948 - val_loss: 0.1299 - val_accuracy: 0.9759
# Epoch 32/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0193 - accuracy: 0.9948 - val_loss: 0.1321 - val_accuracy: 0.9794
# Epoch 33/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0356 - accuracy: 0.9897 - val_loss: 0.7622 - val_accuracy: 0.8797
# Epoch 34/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1851 - accuracy: 0.9500 - val_loss: 1.9471 - val_accuracy: 0.6942
# Epoch 35/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1350 - accuracy: 0.9604 - val_loss: 0.8288 - val_accuracy: 0.8247
# Epoch 36/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1277 - accuracy: 0.9699 - val_loss: 1.3905 - val_accuracy: 0.8007
# Epoch 37/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0570 - accuracy: 0.9802 - val_loss: 0.8748 - val_accuracy: 0.8213
# Epoch 38/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.1604 - val_accuracy: 0.9553
# Epoch 39/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0160 - accuracy: 0.9931 - val_loss: 0.1082 - val_accuracy: 0.9725
# Epoch 40/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0290 - accuracy: 0.9905 - val_loss: 0.4000 - val_accuracy: 0.9141
# Epoch 41/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0503 - accuracy: 0.9828 - val_loss: 0.8837 - val_accuracy: 0.8316
# Epoch 42/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0368 - accuracy: 0.9914 - val_loss: 0.5423 - val_accuracy: 0.8832
# Epoch 43/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0265 - accuracy: 0.9905 - val_loss: 0.6071 - val_accuracy: 0.8969
# Epoch 44/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0324 - accuracy: 0.9888 - val_loss: 0.5474 - val_accuracy: 0.8935
# Epoch 45/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0232 - accuracy: 0.9922 - val_loss: 0.6457 - val_accuracy: 0.8763
# Epoch 46/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0354 - accuracy: 0.9905 - val_loss: 0.2189 - val_accuracy: 0.9313
# Epoch 47/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0212 - accuracy: 0.9922 - val_loss: 0.0979 - val_accuracy: 0.9759
# Epoch 48/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0476 - accuracy: 0.9879 - val_loss: 2.1153 - val_accuracy: 0.6804
# Epoch 49/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0550 - accuracy: 0.9888 - val_loss: 0.2616 - val_accuracy: 0.9485
# Epoch 50/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.1491 - val_accuracy: 0.9725
# 291/291 [==============================] - 1s 2ms/step
# accuracy: 97.25%
# k =  2
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 83s 71ms/step - loss: 0.0664 - accuracy: 0.9828 - val_loss: 0.0105 - val_accuracy: 0.9966
# Epoch 2/50
# 1162/1162 [==============================] - 17s 15ms/step - loss: 0.0747 - accuracy: 0.9819 - val_loss: 0.7030 - val_accuracy: 0.8483
# Epoch 3/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0291 - accuracy: 0.9923 - val_loss: 0.0430 - val_accuracy: 0.9862
# Epoch 4/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0127 - val_accuracy: 0.9966
# Epoch 5/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0073 - accuracy: 0.9966 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 6/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0241 - accuracy: 0.9966 - val_loss: 0.0063 - val_accuracy: 0.9966
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0783 - accuracy: 0.9854 - val_loss: 1.7530 - val_accuracy: 0.6966
# Epoch 8/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0346 - accuracy: 0.9897 - val_loss: 0.2638 - val_accuracy: 0.9207
# Epoch 9/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0265 - accuracy: 0.9940 - val_loss: 0.1248 - val_accuracy: 0.9586
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0776 - accuracy: 0.9793 - val_loss: 0.2032 - val_accuracy: 0.9483
# Epoch 11/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0506 - accuracy: 0.9862 - val_loss: 0.1346 - val_accuracy: 0.9448
# Epoch 12/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0559 - accuracy: 0.9862 - val_loss: 0.3050 - val_accuracy: 0.9207
# Epoch 13/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0246 - accuracy: 0.9931 - val_loss: 0.0591 - val_accuracy: 0.9862
# Epoch 14/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0230 - accuracy: 0.9957 - val_loss: 0.0560 - val_accuracy: 0.9897
# Epoch 15/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0055 - accuracy: 0.9991 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 16/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0083 - accuracy: 0.9966 - val_loss: 0.0185 - val_accuracy: 0.9966
# Epoch 17/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0095 - accuracy: 0.9957 - val_loss: 0.0484 - val_accuracy: 0.9862
# Epoch 18/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0137 - accuracy: 0.9957 - val_loss: 0.0126 - val_accuracy: 0.9966
# Epoch 19/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 20/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 6.2257e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 21/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 5.9141e-04 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 22/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 6.8461e-04 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 23/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 24/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0648 - accuracy: 0.9871 - val_loss: 6.0704 - val_accuracy: 0.4655
# Epoch 25/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.2974 - accuracy: 0.9337 - val_loss: 2.8575 - val_accuracy: 0.6828
# Epoch 26/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.1443 - accuracy: 0.9639 - val_loss: 3.6710 - val_accuracy: 0.6103
# Epoch 27/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0722 - accuracy: 0.9871 - val_loss: 0.2957 - val_accuracy: 0.9276
# Epoch 28/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0225 - accuracy: 0.9948 - val_loss: 0.0350 - val_accuracy: 0.9897
# Epoch 29/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0135 - val_accuracy: 0.9966
# Epoch 30/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0106 - val_accuracy: 0.9966
# Epoch 31/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0054 - val_accuracy: 0.9966
# Epoch 32/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0117 - val_accuracy: 0.9931
# Epoch 33/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9966
# Epoch 34/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9966
# Epoch 35/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 5.2761e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9966
# Epoch 36/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9966
# Epoch 37/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 8.6162e-04 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9966
# Epoch 38/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 5.4595e-04 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 0.9966
# Epoch 39/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 7.0885e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9966
# Epoch 40/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 4.3331e-04 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 0.9966
# Epoch 41/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 2.5029e-04 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 42/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0165 - accuracy: 0.9974 - val_loss: 0.0145 - val_accuracy: 0.9931
# Epoch 43/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0177 - accuracy: 0.9940 - val_loss: 0.3394 - val_accuracy: 0.9103
# Epoch 44/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0921 - accuracy: 0.9793 - val_loss: 1.7054 - val_accuracy: 0.7000
# Epoch 45/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0813 - accuracy: 0.9793 - val_loss: 21.4163 - val_accuracy: 0.1724
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1422 - accuracy: 0.9621 - val_loss: 9.3820 - val_accuracy: 0.4414
# Epoch 47/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.1147 - accuracy: 0.9716 - val_loss: 0.3085 - val_accuracy: 0.9103
# Epoch 48/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0547 - accuracy: 0.9828 - val_loss: 0.2035 - val_accuracy: 0.9483
# Epoch 49/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0242 - accuracy: 0.9897 - val_loss: 0.0203 - val_accuracy: 0.9966
# Epoch 50/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0089 - accuracy: 0.9966 - val_loss: 0.0106 - val_accuracy: 0.9966
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 99.66%
# k =  3
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 84s 72ms/step - loss: 0.0404 - accuracy: 0.9914 - val_loss: 0.1217 - val_accuracy: 0.9724
# Epoch 2/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0413 - accuracy: 0.9871 - val_loss: 0.1230 - val_accuracy: 0.9759
# Epoch 3/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.0241 - val_accuracy: 0.9966
# Epoch 4/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0374 - accuracy: 0.9940 - val_loss: 0.3961 - val_accuracy: 0.9379
# Epoch 5/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.2577 - val_accuracy: 0.9759
# Epoch 6/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0077 - accuracy: 0.9966 - val_loss: 0.0194 - val_accuracy: 0.9931
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0112 - val_accuracy: 0.9966
# Epoch 8/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 8.1516e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9966
# Epoch 9/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0148 - val_accuracy: 0.9931
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0082 - accuracy: 0.9983 - val_loss: 0.0209 - val_accuracy: 0.9966
# Epoch 11/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9966
# Epoch 12/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0035 - accuracy: 0.9983 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 13/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 8.2525e-04 - val_accuracy: 1.0000
# Epoch 14/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0713 - accuracy: 0.9880 - val_loss: 0.0829 - val_accuracy: 0.9793
# Epoch 15/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0721 - accuracy: 0.9785 - val_loss: 0.5846 - val_accuracy: 0.8724
# Epoch 16/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0326 - accuracy: 0.9923 - val_loss: 0.1996 - val_accuracy: 0.9586
# Epoch 17/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0687 - accuracy: 0.9862 - val_loss: 3.3273 - val_accuracy: 0.7345
# Epoch 18/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0337 - accuracy: 0.9931 - val_loss: 0.0708 - val_accuracy: 0.9759
# Epoch 19/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.3338 - val_accuracy: 0.9448
# Epoch 20/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0340 - accuracy: 0.9888 - val_loss: 0.5371 - val_accuracy: 0.9103
# Epoch 21/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0468 - accuracy: 0.9923 - val_loss: 0.8481 - val_accuracy: 0.8310
# Epoch 22/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0450 - accuracy: 0.9862 - val_loss: 0.4413 - val_accuracy: 0.9138
# Epoch 23/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0373 - accuracy: 0.9888 - val_loss: 0.4000 - val_accuracy: 0.9241
# Epoch 24/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0447 - accuracy: 0.9931 - val_loss: 0.0739 - val_accuracy: 0.9793
# Epoch 25/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0383 - accuracy: 0.9931 - val_loss: 0.3962 - val_accuracy: 0.9207
# Epoch 26/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0182 - accuracy: 0.9948 - val_loss: 0.6792 - val_accuracy: 0.8897
# Epoch 27/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0506 - val_accuracy: 0.9828
# Epoch 28/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0148 - accuracy: 0.9957 - val_loss: 0.0466 - val_accuracy: 0.9862
# Epoch 29/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0445 - val_accuracy: 0.9931
# Epoch 30/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0091 - accuracy: 0.9948 - val_loss: 0.0587 - val_accuracy: 0.9862
# Epoch 31/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0072 - accuracy: 0.9957 - val_loss: 0.0700 - val_accuracy: 0.9828
# Epoch 32/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0070 - accuracy: 0.9948 - val_loss: 0.0284 - val_accuracy: 0.9897
# Epoch 33/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0585 - val_accuracy: 0.9793
# Epoch 34/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0058 - accuracy: 0.9991 - val_loss: 0.0370 - val_accuracy: 0.9897
# Epoch 35/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0645 - val_accuracy: 0.9897
# Epoch 36/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0525 - val_accuracy: 0.9931
# Epoch 37/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0646 - val_accuracy: 0.9931
# Epoch 38/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 0.0597 - val_accuracy: 0.9931
# Epoch 39/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 4.7570e-04 - accuracy: 1.0000 - val_loss: 0.0573 - val_accuracy: 0.9931
# Epoch 40/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 1.8257e-04 - accuracy: 1.0000 - val_loss: 0.0408 - val_accuracy: 0.9931
# Epoch 41/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0015 - accuracy: 0.9991 - val_loss: 0.0797 - val_accuracy: 0.9897
# Epoch 42/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0169 - accuracy: 0.9966 - val_loss: 0.0676 - val_accuracy: 0.9793
# Epoch 43/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.1804 - val_accuracy: 0.9724
# Epoch 44/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0723 - accuracy: 0.9854 - val_loss: 2.4319 - val_accuracy: 0.7448
# Epoch 45/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0340 - accuracy: 0.9897 - val_loss: 0.0436 - val_accuracy: 0.9862
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0073 - accuracy: 0.9966 - val_loss: 0.1321 - val_accuracy: 0.9655
# Epoch 47/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0370 - accuracy: 0.9931 - val_loss: 0.0579 - val_accuracy: 0.9862
# Epoch 48/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0666 - accuracy: 0.9862 - val_loss: 0.2364 - val_accuracy: 0.9414
# Epoch 49/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0608 - accuracy: 0.9897 - val_loss: 7.5810 - val_accuracy: 0.5138
# Epoch 50/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0434 - accuracy: 0.9905 - val_loss: 0.2956 - val_accuracy: 0.9345
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 93.45%
# k =  4
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 81s 70ms/step - loss: 0.0265 - accuracy: 0.9931 - val_loss: 0.0070 - val_accuracy: 0.9966
# Epoch 2/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0274 - accuracy: 0.9923 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 3/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0222 - accuracy: 0.9940 - val_loss: 0.2794 - val_accuracy: 0.9310
# Epoch 4/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0422 - accuracy: 0.9905 - val_loss: 0.4543 - val_accuracy: 0.9310
# Epoch 5/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0484 - accuracy: 0.9888 - val_loss: 0.0113 - val_accuracy: 0.9966
# Epoch 6/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 2.1186e-04 - val_accuracy: 1.0000
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 7.4730e-04 - accuracy: 1.0000 - val_loss: 1.7839e-04 - val_accuracy: 1.0000
# Epoch 8/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 7.0674e-05 - val_accuracy: 1.0000
# Epoch 9/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0241 - accuracy: 0.9940 - val_loss: 0.0272 - val_accuracy: 0.9931
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0112 - accuracy: 0.9957 - val_loss: 0.0517 - val_accuracy: 0.9862
# Epoch 11/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0122 - accuracy: 0.9957 - val_loss: 0.1246 - val_accuracy: 0.9724
# Epoch 12/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0816 - val_accuracy: 0.9897
# Epoch 13/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0260 - accuracy: 0.9931 - val_loss: 0.0369 - val_accuracy: 0.9897
# Epoch 14/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0628 - accuracy: 0.9905 - val_loss: 0.0478 - val_accuracy: 0.9862
# Epoch 15/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0310 - accuracy: 0.9914 - val_loss: 0.3678 - val_accuracy: 0.9310
# Epoch 16/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0111 - accuracy: 0.9957 - val_loss: 0.0204 - val_accuracy: 0.9931
# Epoch 17/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9966
# Epoch 18/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0064 - accuracy: 0.9991 - val_loss: 0.0148 - val_accuracy: 0.9931
# Epoch 19/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0219 - val_accuracy: 0.9966
# Epoch 20/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 2.0106e-04 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 0.9966
# Epoch 21/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0037 - accuracy: 0.9983 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 22/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0088 - val_accuracy: 0.9966
# Epoch 23/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 4.5465e-04 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9966
# Epoch 24/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 5.9859e-04 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9966
# Epoch 25/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 6.1095e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9966
# Epoch 26/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0192 - accuracy: 0.9966 - val_loss: 0.0375 - val_accuracy: 0.9897
# Epoch 27/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0135 - accuracy: 0.9966 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 28/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0639 - accuracy: 0.9828 - val_loss: 0.7040 - val_accuracy: 0.8793
# Epoch 29/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0862 - accuracy: 0.9768 - val_loss: 0.0411 - val_accuracy: 0.9897
# Epoch 30/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0226 - accuracy: 0.9905 - val_loss: 0.1071 - val_accuracy: 0.9828
# Epoch 31/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0553 - accuracy: 0.9871 - val_loss: 0.3671 - val_accuracy: 0.9241
# Epoch 32/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0897 - accuracy: 0.9862 - val_loss: 0.2268 - val_accuracy: 0.9621
# Epoch 33/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0162 - accuracy: 0.9931 - val_loss: 0.0501 - val_accuracy: 0.9897
# Epoch 34/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0184 - accuracy: 0.9957 - val_loss: 0.0219 - val_accuracy: 0.9897
# Epoch 35/50
# 1162/1162 [==============================] - 21s 18ms/step - loss: 0.0451 - accuracy: 0.9931 - val_loss: 0.0284 - val_accuracy: 0.9931
# Epoch 36/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0214 - accuracy: 0.9948 - val_loss: 0.0105 - val_accuracy: 0.9931
# Epoch 37/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0193 - accuracy: 0.9966 - val_loss: 0.0086 - val_accuracy: 0.9931
# Epoch 38/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0066 - accuracy: 0.9974 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 39/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0409 - val_accuracy: 0.9931
# Epoch 40/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.0087 - val_accuracy: 0.9931
# Epoch 41/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 4.8766e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9966
# Epoch 42/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 2.2078e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9931
# Epoch 43/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 5.4161e-04 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9966
# Epoch 44/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 1.4322e-04 - accuracy: 1.0000 - val_loss: 0.0120 - val_accuracy: 0.9966
# Epoch 45/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 0.0391 - val_accuracy: 0.9862
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0310 - val_accuracy: 0.9897
# Epoch 47/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0527 - accuracy: 0.9905 - val_loss: 0.2846 - val_accuracy: 0.9517
# Epoch 48/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0469 - accuracy: 0.9905 - val_loss: 0.1107 - val_accuracy: 0.9862
# Epoch 49/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0560 - accuracy: 0.9880 - val_loss: 1.2037 - val_accuracy: 0.8828
# Epoch 50/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0258 - accuracy: 0.9905 - val_loss: 0.1054 - val_accuracy: 0.9793
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 97.93%
# 96.63% (+/- 2.22%)
# CPU times: user 1h 46min 39s, sys: 9min 13s, total: 1h 55min 52s
# Wall time: 1h 32min 58s

# %%
# summarize history for accuracy
filename = '/content/drive/My Drive/Notebook/Training_Files/history_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        25
#            3       0.90      0.95      0.92        19
#            4       0.92      1.00      0.96        23
#            5       0.96      0.92      0.94        24
#            6       1.00      0.95      0.98        21
#            7       1.00      1.00      1.00         2
#            8       0.67      1.00      0.80         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         8
#           12       0.89      1.00      0.94        16
#           13       1.00      1.00      1.00        11
#           14       1.00      1.00      1.00        11
#           15       1.00      1.00      1.00        11
#           16       1.00      1.00      1.00         5
#           17       0.79      0.92      0.85        12
#           18       1.00      0.90      0.95        10
#           19       0.91      1.00      0.95        10
#           20       1.00      1.00      1.00        11
#           21       0.91      0.83      0.87        12
#           22       0.90      1.00      0.95        18
#           23       1.00      0.75      0.86        24
#           24       1.00      0.88      0.94        17
#           25       1.00      1.00      1.00         3
#           26       0.82      1.00      0.90         9
#           27       1.00      0.96      0.98        28
#
#     accuracy                           0.95       363
#    macro avg       0.95      0.97      0.96       363
# weighted avg       0.96      0.95      0.95       363

# %% [markdown]
# ### **Next SD**

# %%
# %reset_selective -f data_train
# %reset_selective -f data_test
# %reset_selective -f y_train
# %reset_selective -f y_test
# %reset_selective -f loaded_train
# %reset_selective -f loaded_test
# %reset_selective -f model
sns.reset_orig()

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42
dtype = 'SD'
data_train, data_test, y_train, y_test = train_test_split(
data_sd, label_sd, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %%
# %%time
K.clear_session()
model = densenet(input_shape, n_classes, f=f)
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('DenseNet')
    filename = '/content/drive/My Drive/Notebook/Training_Files/DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 76s 65ms/step - loss: 2.8559 - accuracy: 0.1912 - val_loss: 3.3462 - val_accuracy: 0.0481
# Epoch 2/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 1.8643 - accuracy: 0.3997 - val_loss: 4.4173 - val_accuracy: 0.0481
# Epoch 3/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 1.4314 - accuracy: 0.5340 - val_loss: 6.5835 - val_accuracy: 0.0412
# Epoch 4/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 1.1475 - accuracy: 0.6202 - val_loss: 4.1924 - val_accuracy: 0.1065
# Epoch 5/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.9252 - accuracy: 0.6839 - val_loss: 3.7173 - val_accuracy: 0.1237
# Epoch 6/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.6612 - accuracy: 0.7786 - val_loss: 3.6024 - val_accuracy: 0.2474
# Epoch 7/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.5661 - accuracy: 0.8096 - val_loss: 6.6668 - val_accuracy: 0.1031
# Epoch 8/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.4761 - accuracy: 0.8363 - val_loss: 8.6805 - val_accuracy: 0.1512
# Epoch 9/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.4597 - accuracy: 0.8415 - val_loss: 4.9546 - val_accuracy: 0.2577
# Epoch 10/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.4251 - accuracy: 0.8544 - val_loss: 3.7766 - val_accuracy: 0.3436
# Epoch 11/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.3321 - accuracy: 0.9009 - val_loss: 4.0788 - val_accuracy: 0.2818
# Epoch 12/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2911 - accuracy: 0.9018 - val_loss: 5.1394 - val_accuracy: 0.2921
# Epoch 13/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2826 - accuracy: 0.9078 - val_loss: 4.2685 - val_accuracy: 0.2921
# Epoch 14/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.2503 - accuracy: 0.9113 - val_loss: 4.5854 - val_accuracy: 0.3299
# Epoch 15/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1748 - accuracy: 0.9337 - val_loss: 5.6153 - val_accuracy: 0.2577
# Epoch 16/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1968 - accuracy: 0.9371 - val_loss: 10.7482 - val_accuracy: 0.1134
# Epoch 17/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2469 - accuracy: 0.9147 - val_loss: 4.7555 - val_accuracy: 0.3024
# Epoch 18/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1961 - accuracy: 0.9397 - val_loss: 1.8815 - val_accuracy: 0.5842
# Epoch 19/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1990 - accuracy: 0.9345 - val_loss: 3.0966 - val_accuracy: 0.4364
# Epoch 20/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2129 - accuracy: 0.9328 - val_loss: 10.3343 - val_accuracy: 0.1340
# Epoch 21/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1767 - accuracy: 0.9466 - val_loss: 5.4385 - val_accuracy: 0.2715
# Epoch 22/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2040 - accuracy: 0.9294 - val_loss: 8.5263 - val_accuracy: 0.2612
# Epoch 23/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.2108 - accuracy: 0.9276 - val_loss: 5.0560 - val_accuracy: 0.2646
# Epoch 24/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1529 - accuracy: 0.9406 - val_loss: 2.0676 - val_accuracy: 0.5739
# Epoch 25/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2056 - accuracy: 0.9285 - val_loss: 3.8898 - val_accuracy: 0.4330
# Epoch 26/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1383 - accuracy: 0.9595 - val_loss: 3.5385 - val_accuracy: 0.4124
# Epoch 27/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0949 - accuracy: 0.9724 - val_loss: 2.2186 - val_accuracy: 0.5739
# Epoch 28/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0831 - accuracy: 0.9733 - val_loss: 2.3616 - val_accuracy: 0.5636
# Epoch 29/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0391 - accuracy: 0.9888 - val_loss: 2.4159 - val_accuracy: 0.5533
# Epoch 30/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0613 - accuracy: 0.9802 - val_loss: 2.9302 - val_accuracy: 0.4742
# Epoch 31/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1062 - accuracy: 0.9673 - val_loss: 2.1718 - val_accuracy: 0.5670
# Epoch 32/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1608 - accuracy: 0.9449 - val_loss: 6.2432 - val_accuracy: 0.2818
# Epoch 33/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1214 - accuracy: 0.9647 - val_loss: 4.3046 - val_accuracy: 0.4296
# Epoch 34/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1429 - accuracy: 0.9630 - val_loss: 1.8004 - val_accuracy: 0.6735
# Epoch 35/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0958 - accuracy: 0.9647 - val_loss: 3.8070 - val_accuracy: 0.4089
# Epoch 36/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1641 - accuracy: 0.9509 - val_loss: 7.1176 - val_accuracy: 0.3196
# Epoch 37/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1329 - accuracy: 0.9578 - val_loss: 2.9254 - val_accuracy: 0.5498
# Epoch 38/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0397 - accuracy: 0.9888 - val_loss: 1.4842 - val_accuracy: 0.6873
# Epoch 39/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0188 - accuracy: 0.9948 - val_loss: 1.2308 - val_accuracy: 0.7251
# Epoch 40/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1168 - accuracy: 0.9621 - val_loss: 9.3710 - val_accuracy: 0.1787
# Epoch 41/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1830 - accuracy: 0.9363 - val_loss: 11.4644 - val_accuracy: 0.1718
# Epoch 42/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1551 - accuracy: 0.9535 - val_loss: 4.9449 - val_accuracy: 0.3746
# Epoch 43/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1157 - accuracy: 0.9630 - val_loss: 1.6139 - val_accuracy: 0.7113
# Epoch 44/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1162 - accuracy: 0.9561 - val_loss: 13.3378 - val_accuracy: 0.1787
# Epoch 45/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1356 - accuracy: 0.9578 - val_loss: 5.7905 - val_accuracy: 0.3505
# Epoch 46/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1230 - accuracy: 0.9612 - val_loss: 4.2206 - val_accuracy: 0.4227
# Epoch 47/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0562 - accuracy: 0.9793 - val_loss: 3.1824 - val_accuracy: 0.5361
# Epoch 48/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0615 - accuracy: 0.9811 - val_loss: 2.1305 - val_accuracy: 0.6495
# Epoch 49/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0674 - accuracy: 0.9811 - val_loss: 3.6970 - val_accuracy: 0.4948
# Epoch 50/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0311 - accuracy: 0.9897 - val_loss: 3.6827 - val_accuracy: 0.5017
# 291/291 [==============================] - 1s 2ms/step
# accuracy: 50.17%
# k =  1
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 79s 68ms/step - loss: 0.3737 - accuracy: 0.9053 - val_loss: 3.3508 - val_accuracy: 0.6186
# Epoch 2/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2091 - accuracy: 0.9406 - val_loss: 9.4319 - val_accuracy: 0.3058
# Epoch 3/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1791 - accuracy: 0.9526 - val_loss: 0.7259 - val_accuracy: 0.8179
# Epoch 4/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0884 - accuracy: 0.9664 - val_loss: 0.4175 - val_accuracy: 0.8694
# Epoch 5/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1662 - accuracy: 0.9500 - val_loss: 2.0992 - val_accuracy: 0.5911
# Epoch 6/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1306 - accuracy: 0.9587 - val_loss: 3.3404 - val_accuracy: 0.5155
# Epoch 7/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1320 - accuracy: 0.9604 - val_loss: 1.1140 - val_accuracy: 0.7113
# Epoch 8/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1167 - accuracy: 0.9587 - val_loss: 0.8710 - val_accuracy: 0.7526
# Epoch 9/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1054 - accuracy: 0.9724 - val_loss: 2.5174 - val_accuracy: 0.5052
# Epoch 10/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1444 - accuracy: 0.9569 - val_loss: 3.1357 - val_accuracy: 0.4742
# Epoch 11/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1126 - accuracy: 0.9647 - val_loss: 3.2289 - val_accuracy: 0.4708
# Epoch 12/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.0808 - accuracy: 0.9742 - val_loss: 1.1974 - val_accuracy: 0.7320
# Epoch 13/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0301 - accuracy: 0.9879 - val_loss: 0.2549 - val_accuracy: 0.9347
# Epoch 14/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0164 - accuracy: 0.9957 - val_loss: 0.2600 - val_accuracy: 0.9141
# Epoch 15/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0938 - accuracy: 0.9716 - val_loss: 1.5955 - val_accuracy: 0.6357
# Epoch 16/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0824 - accuracy: 0.9724 - val_loss: 0.4765 - val_accuracy: 0.8591
# Epoch 17/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0812 - accuracy: 0.9759 - val_loss: 2.7379 - val_accuracy: 0.6117
# Epoch 18/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.0950 - accuracy: 0.9716 - val_loss: 3.7211 - val_accuracy: 0.4605
# Epoch 19/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0958 - accuracy: 0.9699 - val_loss: 4.4834 - val_accuracy: 0.4570
# Epoch 20/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1407 - accuracy: 0.9569 - val_loss: 3.8387 - val_accuracy: 0.4192
# Epoch 21/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1687 - accuracy: 0.9526 - val_loss: 9.1581 - val_accuracy: 0.2509
# Epoch 22/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1375 - accuracy: 0.9604 - val_loss: 2.5158 - val_accuracy: 0.5670
# Epoch 23/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0851 - accuracy: 0.9750 - val_loss: 2.8845 - val_accuracy: 0.5464
# Epoch 24/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1118 - accuracy: 0.9699 - val_loss: 1.1517 - val_accuracy: 0.7835
# Epoch 25/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0358 - accuracy: 0.9888 - val_loss: 0.2882 - val_accuracy: 0.9278
# Epoch 26/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1357 - accuracy: 0.9673 - val_loss: 3.0502 - val_accuracy: 0.5395
# Epoch 27/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0628 - accuracy: 0.9871 - val_loss: 0.5592 - val_accuracy: 0.8522
# Epoch 28/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0248 - accuracy: 0.9914 - val_loss: 0.8073 - val_accuracy: 0.7801
# Epoch 29/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.2873 - val_accuracy: 0.9416
# Epoch 30/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.2293 - val_accuracy: 0.9416
# Epoch 31/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0139 - accuracy: 0.9991 - val_loss: 0.3823 - val_accuracy: 0.9003
# Epoch 32/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0278 - accuracy: 0.9940 - val_loss: 0.5771 - val_accuracy: 0.8763
# Epoch 33/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0487 - accuracy: 0.9879 - val_loss: 1.3918 - val_accuracy: 0.6838
# Epoch 34/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0475 - accuracy: 0.9879 - val_loss: 3.7492 - val_accuracy: 0.4605
# Epoch 35/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0232 - accuracy: 0.9931 - val_loss: 1.1918 - val_accuracy: 0.7423
# Epoch 36/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0247 - accuracy: 0.9931 - val_loss: 0.2443 - val_accuracy: 0.9107
# Epoch 37/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0239 - accuracy: 0.9914 - val_loss: 1.2437 - val_accuracy: 0.7595
# Epoch 38/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0198 - accuracy: 0.9957 - val_loss: 1.2481 - val_accuracy: 0.7182
# Epoch 39/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0829 - accuracy: 0.9785 - val_loss: 1.3348 - val_accuracy: 0.7113
# Epoch 40/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1105 - accuracy: 0.9699 - val_loss: 1.9726 - val_accuracy: 0.6117
# Epoch 41/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1049 - accuracy: 0.9707 - val_loss: 5.2116 - val_accuracy: 0.4192
# Epoch 42/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0713 - accuracy: 0.9785 - val_loss: 5.7641 - val_accuracy: 0.3780
# Epoch 43/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1406 - accuracy: 0.9673 - val_loss: 5.4898 - val_accuracy: 0.3780
# Epoch 44/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1550 - accuracy: 0.9500 - val_loss: 7.8857 - val_accuracy: 0.3643
# Epoch 45/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0995 - accuracy: 0.9716 - val_loss: 12.0645 - val_accuracy: 0.3058
# Epoch 46/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.0649 - accuracy: 0.9793 - val_loss: 1.7094 - val_accuracy: 0.6976
# Epoch 47/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1187 - accuracy: 0.9699 - val_loss: 3.3753 - val_accuracy: 0.5120
# Epoch 48/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0823 - accuracy: 0.9819 - val_loss: 0.5947 - val_accuracy: 0.8832
# Epoch 49/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0238 - accuracy: 0.9940 - val_loss: 0.5783 - val_accuracy: 0.8763
# Epoch 50/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0311 - accuracy: 0.9931 - val_loss: 0.4058 - val_accuracy: 0.8935
# 291/291 [==============================] - 1s 2ms/step
# accuracy: 89.35%
# k =  2
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 79s 68ms/step - loss: 0.1300 - accuracy: 0.9673 - val_loss: 0.2531 - val_accuracy: 0.9345
# Epoch 2/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.1158 - accuracy: 0.9690 - val_loss: 1.5800 - val_accuracy: 0.6966
# Epoch 3/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0398 - accuracy: 0.9828 - val_loss: 0.1212 - val_accuracy: 0.9621
# Epoch 4/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0742 - accuracy: 0.9845 - val_loss: 0.5721 - val_accuracy: 0.8690
# Epoch 5/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0716 - accuracy: 0.9811 - val_loss: 1.3181 - val_accuracy: 0.7517
# Epoch 6/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0766 - accuracy: 0.9811 - val_loss: 0.3170 - val_accuracy: 0.8966
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0691 - accuracy: 0.9819 - val_loss: 0.2778 - val_accuracy: 0.9069
# Epoch 8/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0891 - accuracy: 0.9733 - val_loss: 1.1257 - val_accuracy: 0.7621
# Epoch 9/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0614 - accuracy: 0.9811 - val_loss: 0.4816 - val_accuracy: 0.8828
# Epoch 10/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0499 - accuracy: 0.9854 - val_loss: 0.8093 - val_accuracy: 0.8103
# Epoch 11/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0660 - accuracy: 0.9776 - val_loss: 0.9580 - val_accuracy: 0.7862
# Epoch 12/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.2118 - val_accuracy: 0.9483
# Epoch 13/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.0890 - val_accuracy: 0.9655
# Epoch 14/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0320 - accuracy: 0.9905 - val_loss: 0.6351 - val_accuracy: 0.8241
# Epoch 15/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0486 - accuracy: 0.9836 - val_loss: 1.0559 - val_accuracy: 0.7621
# Epoch 16/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0693 - accuracy: 0.9802 - val_loss: 0.2707 - val_accuracy: 0.9345
# Epoch 17/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0735 - accuracy: 0.9802 - val_loss: 3.0864 - val_accuracy: 0.5966
# Epoch 18/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0452 - accuracy: 0.9845 - val_loss: 0.0595 - val_accuracy: 0.9828
# Epoch 19/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0969 - accuracy: 0.9716 - val_loss: 0.4617 - val_accuracy: 0.8552
# Epoch 20/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0559 - accuracy: 0.9845 - val_loss: 0.4570 - val_accuracy: 0.8931
# Epoch 21/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0285 - accuracy: 0.9948 - val_loss: 0.0815 - val_accuracy: 0.9655
# Epoch 22/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 0.0610 - val_accuracy: 0.9897
# Epoch 23/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0075 - accuracy: 0.9983 - val_loss: 0.2360 - val_accuracy: 0.9379
# Epoch 24/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0240 - accuracy: 0.9923 - val_loss: 0.3577 - val_accuracy: 0.8897
# Epoch 25/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0839 - accuracy: 0.9793 - val_loss: 0.8340 - val_accuracy: 0.8276
# Epoch 26/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0982 - accuracy: 0.9759 - val_loss: 1.9491 - val_accuracy: 0.6759
# Epoch 27/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0471 - accuracy: 0.9828 - val_loss: 0.4138 - val_accuracy: 0.8828
# Epoch 28/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.1199 - accuracy: 0.9742 - val_loss: 2.1178 - val_accuracy: 0.6138
# Epoch 29/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0685 - accuracy: 0.9785 - val_loss: 3.1187 - val_accuracy: 0.5621
# Epoch 30/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0402 - accuracy: 0.9897 - val_loss: 1.6102 - val_accuracy: 0.6897
# Epoch 31/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.9569 - val_accuracy: 0.7724
# Epoch 32/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0342 - accuracy: 0.9897 - val_loss: 4.0382 - val_accuracy: 0.5241
# Epoch 33/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0727 - accuracy: 0.9793 - val_loss: 0.8455 - val_accuracy: 0.8103
# Epoch 34/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0412 - accuracy: 0.9914 - val_loss: 0.8528 - val_accuracy: 0.8172
# Epoch 35/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0609 - accuracy: 0.9862 - val_loss: 1.7714 - val_accuracy: 0.7172
# Epoch 36/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0411 - accuracy: 0.9854 - val_loss: 0.3025 - val_accuracy: 0.9276
# Epoch 37/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.1545 - val_accuracy: 0.9586
# Epoch 38/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0296 - accuracy: 0.9931 - val_loss: 2.9070 - val_accuracy: 0.6414
# Epoch 39/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0456 - accuracy: 0.9836 - val_loss: 1.7842 - val_accuracy: 0.6966
# Epoch 40/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0463 - accuracy: 0.9862 - val_loss: 1.1906 - val_accuracy: 0.7552
# Epoch 41/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0403 - accuracy: 0.9905 - val_loss: 0.5445 - val_accuracy: 0.8931
# Epoch 42/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.1995 - val_accuracy: 0.9414
# Epoch 43/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.1951 - val_accuracy: 0.9552
# Epoch 44/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0374 - accuracy: 0.9914 - val_loss: 0.6543 - val_accuracy: 0.8414
# Epoch 45/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0321 - accuracy: 0.9905 - val_loss: 0.4539 - val_accuracy: 0.8897
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.2538 - val_accuracy: 0.9207
# Epoch 47/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0377 - accuracy: 0.9931 - val_loss: 1.2700 - val_accuracy: 0.7414
# Epoch 48/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0313 - accuracy: 0.9862 - val_loss: 2.9447 - val_accuracy: 0.6069
# Epoch 49/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0300 - accuracy: 0.9905 - val_loss: 3.1707 - val_accuracy: 0.5724
# Epoch 50/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0522 - accuracy: 0.9871 - val_loss: 1.7521 - val_accuracy: 0.7000
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 70.00%
# k =  3
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 82s 71ms/step - loss: 0.0702 - accuracy: 0.9819 - val_loss: 0.0600 - val_accuracy: 0.9759
# Epoch 2/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0306 - accuracy: 0.9888 - val_loss: 0.0499 - val_accuracy: 0.9793
# Epoch 3/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0818 - accuracy: 0.9802 - val_loss: 15.2941 - val_accuracy: 0.3034
# Epoch 4/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0725 - accuracy: 0.9845 - val_loss: 0.8344 - val_accuracy: 0.8172
# Epoch 5/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.1289 - accuracy: 0.9656 - val_loss: 2.8525 - val_accuracy: 0.6207
# Epoch 6/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0699 - accuracy: 0.9802 - val_loss: 0.4940 - val_accuracy: 0.8966
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0337 - accuracy: 0.9871 - val_loss: 0.0846 - val_accuracy: 0.9690
# Epoch 8/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0056 - accuracy: 0.9974 - val_loss: 0.0293 - val_accuracy: 0.9931
# Epoch 9/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0230 - val_accuracy: 0.9931
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.0564 - val_accuracy: 0.9759
# Epoch 11/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0206 - accuracy: 0.9931 - val_loss: 0.1389 - val_accuracy: 0.9517
# Epoch 12/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0228 - accuracy: 0.9931 - val_loss: 0.1510 - val_accuracy: 0.9586
# Epoch 13/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0201 - accuracy: 0.9966 - val_loss: 0.0074 - val_accuracy: 0.9966
# Epoch 14/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0202 - accuracy: 0.9940 - val_loss: 4.2634 - val_accuracy: 0.4897
# Epoch 15/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.9677 - val_accuracy: 0.7724
# Epoch 16/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.2262 - val_accuracy: 0.9483
# Epoch 17/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0168 - accuracy: 0.9931 - val_loss: 1.5179 - val_accuracy: 0.7138
# Epoch 18/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0183 - accuracy: 0.9957 - val_loss: 1.5401 - val_accuracy: 0.8069
# Epoch 19/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0775 - accuracy: 0.9862 - val_loss: 1.7327 - val_accuracy: 0.7241
# Epoch 20/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0444 - accuracy: 0.9931 - val_loss: 0.7573 - val_accuracy: 0.8345
# Epoch 21/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0679 - accuracy: 0.9768 - val_loss: 2.5654 - val_accuracy: 0.6172
# Epoch 22/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.1162 - accuracy: 0.9750 - val_loss: 7.3706 - val_accuracy: 0.4172
# Epoch 23/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0819 - accuracy: 0.9725 - val_loss: 2.0122 - val_accuracy: 0.7000
# Epoch 24/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0907 - accuracy: 0.9836 - val_loss: 2.7765 - val_accuracy: 0.6448
# Epoch 25/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0820 - accuracy: 0.9819 - val_loss: 0.8708 - val_accuracy: 0.8103
# Epoch 26/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0576 - accuracy: 0.9871 - val_loss: 1.4375 - val_accuracy: 0.7483
# Epoch 27/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0227 - accuracy: 0.9940 - val_loss: 0.0369 - val_accuracy: 0.9931
# Epoch 28/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.2775 - val_accuracy: 0.9241
# Epoch 29/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0485 - accuracy: 0.9897 - val_loss: 0.5239 - val_accuracy: 0.8759
# Epoch 30/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0218 - accuracy: 0.9914 - val_loss: 0.1129 - val_accuracy: 0.9793
# Epoch 31/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0322 - accuracy: 0.9957 - val_loss: 0.0779 - val_accuracy: 0.9862
# Epoch 32/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0215 - accuracy: 0.9957 - val_loss: 0.1245 - val_accuracy: 0.9724
# Epoch 33/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0877 - accuracy: 0.9768 - val_loss: 4.4227 - val_accuracy: 0.5276
# Epoch 34/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.4562 - val_accuracy: 0.9000
# Epoch 35/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0107 - accuracy: 0.9957 - val_loss: 0.1487 - val_accuracy: 0.9552
# Epoch 36/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0028 - accuracy: 0.9983 - val_loss: 0.0293 - val_accuracy: 0.9862
# Epoch 37/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0086 - accuracy: 0.9957 - val_loss: 0.0844 - val_accuracy: 0.9793
# Epoch 38/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0770 - val_accuracy: 0.9793
# Epoch 39/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0029 - accuracy: 0.9983 - val_loss: 0.0690 - val_accuracy: 0.9828
# Epoch 40/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9931
# Epoch 41/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9931
# Epoch 42/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0014 - accuracy: 0.9991 - val_loss: 0.0499 - val_accuracy: 0.9862
# Epoch 43/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0383 - val_accuracy: 0.9931
# Epoch 44/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 4.1847e-04 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 0.9931
# Epoch 45/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 2.6671e-04 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9931
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 1.4364e-04 - accuracy: 1.0000 - val_loss: 0.0422 - val_accuracy: 0.9931
# Epoch 47/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 4.8612e-04 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9897
# Epoch 48/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 3.4063e-04 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9931
# Epoch 49/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 6.6425e-04 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 0.9862
# Epoch 50/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 3.1033e-04 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9897
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 98.97%
# k =  4
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 81s 70ms/step - loss: 0.0520 - accuracy: 0.9871 - val_loss: 0.1255 - val_accuracy: 0.9793
# Epoch 2/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0365 - accuracy: 0.9880 - val_loss: 0.0435 - val_accuracy: 0.9828
# Epoch 3/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0328 - accuracy: 0.9931 - val_loss: 0.2304 - val_accuracy: 0.9345
# Epoch 4/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 5/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 0.1085 - val_accuracy: 0.9552
# Epoch 6/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0178 - val_accuracy: 0.9966
# Epoch 7/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0282 - accuracy: 0.9905 - val_loss: 1.4457 - val_accuracy: 0.7793
# Epoch 8/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1540 - accuracy: 0.9707 - val_loss: 3.5526 - val_accuracy: 0.5931
# Epoch 9/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1328 - accuracy: 0.9699 - val_loss: 1.2917 - val_accuracy: 0.7621
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0690 - accuracy: 0.9776 - val_loss: 0.5085 - val_accuracy: 0.8828
# Epoch 11/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0239 - accuracy: 0.9905 - val_loss: 0.4780 - val_accuracy: 0.8655
# Epoch 12/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0475 - val_accuracy: 0.9828
# Epoch 13/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 14/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 8.8654e-04 - val_accuracy: 1.0000
# Epoch 15/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 7.9347e-04 - accuracy: 1.0000 - val_loss: 7.0625e-04 - val_accuracy: 1.0000
# Epoch 16/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 7.4217e-04 - accuracy: 1.0000 - val_loss: 2.9614e-04 - val_accuracy: 1.0000
# Epoch 17/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 18/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 6.4959e-04 - accuracy: 1.0000 - val_loss: 2.1159e-04 - val_accuracy: 1.0000
# Epoch 19/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 6.4342e-04 - accuracy: 1.0000 - val_loss: 5.7787e-04 - val_accuracy: 1.0000
# Epoch 20/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 3.1435e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9966
# Epoch 21/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9966
# Epoch 22/50
# 1162/1162 [==============================] - 23s 20ms/step - loss: 5.3186e-04 - accuracy: 1.0000 - val_loss: 5.5302e-04 - val_accuracy: 1.0000
# Epoch 23/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 5.6417e-04 - accuracy: 1.0000 - val_loss: 4.2090e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 5.0303e-04 - accuracy: 1.0000 - val_loss: 3.7684e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 5.0988e-04 - accuracy: 1.0000 - val_loss: 2.1503e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0063 - val_accuracy: 0.9966
# Epoch 27/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 28/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 3.7464e-04 - accuracy: 1.0000 - val_loss: 7.9128e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0652 - accuracy: 0.9966 - val_loss: 1.0618 - val_accuracy: 0.8379
# Epoch 30/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.2670 - accuracy: 0.9329 - val_loss: 13.2592 - val_accuracy: 0.3690
# Epoch 31/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.2834 - accuracy: 0.9372 - val_loss: 4.4630 - val_accuracy: 0.7000
# Epoch 32/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1837 - accuracy: 0.9604 - val_loss: 4.3258 - val_accuracy: 0.5069
# Epoch 33/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1230 - accuracy: 0.9707 - val_loss: 5.0333 - val_accuracy: 0.5069
# Epoch 34/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0452 - accuracy: 0.9880 - val_loss: 0.8910 - val_accuracy: 0.8207
# Epoch 35/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0628 - val_accuracy: 0.9759
# Epoch 36/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.0387 - val_accuracy: 0.9862
# Epoch 37/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 0.0600 - val_accuracy: 0.9793
# Epoch 38/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 0.9931
# Epoch 39/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 40/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 41/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 5.7590e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 42/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.0102 - val_accuracy: 0.9966
# Epoch 43/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 44/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 7.9106e-04 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 45/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 3.6303e-04 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 0.9966
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 2.2300e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9966
# Epoch 47/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 3.7134e-04 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 0.9966
# Epoch 48/50
# 1162/1162 [==============================] - 23s 20ms/step - loss: 3.1288e-04 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9966
# Epoch 49/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 2.8683e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 50/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 2.1325e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9966
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 99.66%
# 81.63% (+/- 19.03%)
# CPU times: user 1h 47min 9s, sys: 9min 13s, total: 1h 56min 22s
# Wall time: 1h 33min 2s

# %%
# summarize history for accuracy
filename = '/content/drive/My Drive/Notebook/Training_Files/history_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88        11
#            1       0.67      0.93      0.78        15
#            2       0.92      0.96      0.94        25
#            3       0.94      0.79      0.86        19
#            4       0.96      1.00      0.98        23
#            5       0.95      0.79      0.86        24
#            6       0.77      0.81      0.79        21
#            7       0.67      1.00      0.80         2
#            8       0.67      1.00      0.80         2
#            9       0.67      1.00      0.80         2
#           10       1.00      1.00      1.00         3
#           11       1.00      0.88      0.93         8
#           12       0.83      0.94      0.88        16
#           13       1.00      0.91      0.95        11
#           14       0.77      0.91      0.83        11
#           15       1.00      0.82      0.90        11
#           16       0.83      1.00      0.91         5
#           17       0.71      0.83      0.77        12
#           18       0.75      0.60      0.67        10
#           19       0.82      0.90      0.86        10
#           20       0.91      0.91      0.91        11
#           21       0.92      0.92      0.92        12
#           22       0.94      0.89      0.91        18
#           23       0.78      0.88      0.82        24
#           24       0.77      0.59      0.67        17
#           25       1.00      1.00      1.00         3
#           26       1.00      0.78      0.88         9
#           27       1.00      0.79      0.88        28
#
#     accuracy                           0.86       363
#    macro avg       0.86      0.89      0.86       363
# weighted avg       0.87      0.86      0.86       363

# %% [markdown]
# ### **Next SK**

# %%
# %reset_selective -f data_train
# %reset_selective -f data_test
# %reset_selective -f y_train
# %reset_selective -f y_test
# %reset_selective -f loaded_train
# %reset_selective -f loaded_test
# %reset_selective -f model
sns.reset_orig()

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42
dtype = 'SK'
data_train, data_test, y_train, y_test = train_test_split(
data_sk, label_sk, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %%
# %%time
K.clear_session()
model = densenet(input_shape, n_classes, f=f)
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('DenseNet')
    filename = '/content/drive/My Drive/Notebook/Training_Files/DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 79s 68ms/step - loss: 2.8867 - accuracy: 0.1766 - val_loss: 3.3245 - val_accuracy: 0.0619
# Epoch 2/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 1.9841 - accuracy: 0.3850 - val_loss: 3.9636 - val_accuracy: 0.0447
# Epoch 3/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 1.4242 - accuracy: 0.5357 - val_loss: 4.7602 - val_accuracy: 0.0412
# Epoch 4/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 1.0977 - accuracy: 0.6305 - val_loss: 6.7454 - val_accuracy: 0.0412
# Epoch 5/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.9195 - accuracy: 0.6882 - val_loss: 5.3012 - val_accuracy: 0.0756
# Epoch 6/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.7571 - accuracy: 0.7450 - val_loss: 4.5551 - val_accuracy: 0.1409
# Epoch 7/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.6247 - accuracy: 0.7941 - val_loss: 3.4718 - val_accuracy: 0.2715
# Epoch 8/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.5084 - accuracy: 0.8295 - val_loss: 3.9618 - val_accuracy: 0.2371
# Epoch 9/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.4236 - accuracy: 0.8630 - val_loss: 2.3405 - val_accuracy: 0.3780
# Epoch 10/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2987 - accuracy: 0.9044 - val_loss: 2.2906 - val_accuracy: 0.5430
# Epoch 11/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.3447 - accuracy: 0.8829 - val_loss: 5.5484 - val_accuracy: 0.1718
# Epoch 12/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.3407 - accuracy: 0.8820 - val_loss: 10.8984 - val_accuracy: 0.0790
# Epoch 13/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2865 - accuracy: 0.9044 - val_loss: 9.0293 - val_accuracy: 0.1959
# Epoch 14/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.2154 - accuracy: 0.9276 - val_loss: 8.0678 - val_accuracy: 0.1684
# Epoch 15/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1736 - accuracy: 0.9432 - val_loss: 3.5793 - val_accuracy: 0.3471
# Epoch 16/50
# 1161/1161 [==============================] - 20s 18ms/step - loss: 0.1305 - accuracy: 0.9543 - val_loss: 3.7884 - val_accuracy: 0.3299
# Epoch 17/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1709 - accuracy: 0.9432 - val_loss: 4.9963 - val_accuracy: 0.2405
# Epoch 18/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2080 - accuracy: 0.9354 - val_loss: 3.7171 - val_accuracy: 0.3368
# Epoch 19/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.2593 - accuracy: 0.9216 - val_loss: 13.3447 - val_accuracy: 0.1271
# Epoch 20/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1549 - accuracy: 0.9509 - val_loss: 8.2323 - val_accuracy: 0.1993
# Epoch 21/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1618 - accuracy: 0.9492 - val_loss: 7.0326 - val_accuracy: 0.2955
# Epoch 22/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1320 - accuracy: 0.9612 - val_loss: 4.2856 - val_accuracy: 0.4124
# Epoch 23/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1418 - accuracy: 0.9552 - val_loss: 3.6411 - val_accuracy: 0.3780
# Epoch 24/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.1532 - accuracy: 0.9535 - val_loss: 5.3253 - val_accuracy: 0.2268
# Epoch 25/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1243 - accuracy: 0.9526 - val_loss: 6.5407 - val_accuracy: 0.1684
# Epoch 26/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1349 - accuracy: 0.9604 - val_loss: 2.9154 - val_accuracy: 0.4502
# Epoch 27/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1093 - accuracy: 0.9612 - val_loss: 3.6752 - val_accuracy: 0.4536
# Epoch 28/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1113 - accuracy: 0.9638 - val_loss: 6.4282 - val_accuracy: 0.2234
# Epoch 29/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.2576 - accuracy: 0.9276 - val_loss: 14.9030 - val_accuracy: 0.0825
# Epoch 30/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1900 - accuracy: 0.9397 - val_loss: 4.6439 - val_accuracy: 0.3643
# Epoch 31/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1605 - accuracy: 0.9483 - val_loss: 10.6447 - val_accuracy: 0.2337
# Epoch 32/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1395 - accuracy: 0.9604 - val_loss: 1.9666 - val_accuracy: 0.5773
# Epoch 33/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0637 - accuracy: 0.9742 - val_loss: 2.4579 - val_accuracy: 0.5911
# Epoch 34/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0907 - accuracy: 0.9690 - val_loss: 1.8785 - val_accuracy: 0.6392
# Epoch 35/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0526 - accuracy: 0.9854 - val_loss: 1.8263 - val_accuracy: 0.6460
# Epoch 36/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0624 - accuracy: 0.9802 - val_loss: 1.1123 - val_accuracy: 0.7079
# Epoch 37/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0568 - accuracy: 0.9845 - val_loss: 1.9080 - val_accuracy: 0.6186
# Epoch 38/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0575 - accuracy: 0.9802 - val_loss: 2.9717 - val_accuracy: 0.5017
# Epoch 39/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1854 - accuracy: 0.9449 - val_loss: 6.9439 - val_accuracy: 0.2509
# Epoch 40/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1284 - accuracy: 0.9595 - val_loss: 12.4685 - val_accuracy: 0.1959
# Epoch 41/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1079 - accuracy: 0.9612 - val_loss: 21.3565 - val_accuracy: 0.0550
# Epoch 42/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1175 - accuracy: 0.9621 - val_loss: 10.3675 - val_accuracy: 0.1787
# Epoch 43/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1003 - accuracy: 0.9655 - val_loss: 3.4603 - val_accuracy: 0.4811
# Epoch 44/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1442 - accuracy: 0.9612 - val_loss: 3.5832 - val_accuracy: 0.4708
# Epoch 45/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1262 - accuracy: 0.9716 - val_loss: 12.0597 - val_accuracy: 0.1031
# Epoch 46/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1888 - accuracy: 0.9492 - val_loss: 7.1706 - val_accuracy: 0.3093
# Epoch 47/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0647 - accuracy: 0.9793 - val_loss: 3.2634 - val_accuracy: 0.4742
# Epoch 48/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0716 - accuracy: 0.9785 - val_loss: 5.1856 - val_accuracy: 0.3643
# Epoch 49/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0218 - accuracy: 0.9940 - val_loss: 3.0256 - val_accuracy: 0.5258
# Epoch 50/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0150 - accuracy: 0.9966 - val_loss: 1.3336 - val_accuracy: 0.7148
# 291/291 [==============================] - 1s 2ms/step
# accuracy: 71.48%
# k =  1
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 82s 70ms/step - loss: 0.3949 - accuracy: 0.9078 - val_loss: 13.4086 - val_accuracy: 0.2474
# Epoch 2/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1947 - accuracy: 0.9449 - val_loss: 0.6010 - val_accuracy: 0.8179
# Epoch 3/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1719 - accuracy: 0.9440 - val_loss: 0.5613 - val_accuracy: 0.8385
# Epoch 4/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0754 - accuracy: 0.9759 - val_loss: 0.0428 - val_accuracy: 0.9931
# Epoch 5/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0743 - accuracy: 0.9785 - val_loss: 0.2219 - val_accuracy: 0.9347
# Epoch 6/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0558 - accuracy: 0.9828 - val_loss: 0.2219 - val_accuracy: 0.9278
# Epoch 7/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0984 - accuracy: 0.9647 - val_loss: 2.7986 - val_accuracy: 0.5464
# Epoch 8/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1595 - accuracy: 0.9500 - val_loss: 3.0250 - val_accuracy: 0.5223
# Epoch 9/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1225 - accuracy: 0.9587 - val_loss: 12.7003 - val_accuracy: 0.2302
# Epoch 10/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.2232 - accuracy: 0.9492 - val_loss: 16.2423 - val_accuracy: 0.1787
# Epoch 11/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.1489 - accuracy: 0.9543 - val_loss: 8.6814 - val_accuracy: 0.3299
# Epoch 12/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0823 - accuracy: 0.9724 - val_loss: 1.6454 - val_accuracy: 0.7045
# Epoch 13/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0334 - accuracy: 0.9897 - val_loss: 0.7645 - val_accuracy: 0.8076
# Epoch 14/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0319 - accuracy: 0.9914 - val_loss: 0.4307 - val_accuracy: 0.8832
# Epoch 15/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0383 - accuracy: 0.9905 - val_loss: 0.1677 - val_accuracy: 0.9485
# Epoch 16/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0229 - accuracy: 0.9931 - val_loss: 0.2385 - val_accuracy: 0.9313
# Epoch 17/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0437 - accuracy: 0.9879 - val_loss: 1.4438 - val_accuracy: 0.6701
# Epoch 18/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1492 - accuracy: 0.9587 - val_loss: 4.4325 - val_accuracy: 0.3677
# Epoch 19/50
# 1161/1161 [==============================] - 21s 18ms/step - loss: 0.0987 - accuracy: 0.9681 - val_loss: 3.0072 - val_accuracy: 0.5670
# Epoch 20/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1387 - accuracy: 0.9630 - val_loss: 9.5228 - val_accuracy: 0.3402
# Epoch 21/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1074 - accuracy: 0.9647 - val_loss: 2.1111 - val_accuracy: 0.6357
# Epoch 22/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0720 - accuracy: 0.9742 - val_loss: 0.4532 - val_accuracy: 0.8729
# Epoch 23/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1151 - accuracy: 0.9707 - val_loss: 4.4768 - val_accuracy: 0.4364
# Epoch 24/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0569 - accuracy: 0.9793 - val_loss: 0.2689 - val_accuracy: 0.9313
# Epoch 25/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0590 - accuracy: 0.9828 - val_loss: 1.3824 - val_accuracy: 0.7388
# Epoch 26/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0548 - accuracy: 0.9819 - val_loss: 0.6748 - val_accuracy: 0.8454
# Epoch 27/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0559 - accuracy: 0.9845 - val_loss: 6.4396 - val_accuracy: 0.4777
# Epoch 28/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0288 - accuracy: 0.9914 - val_loss: 5.2631 - val_accuracy: 0.5911
# Epoch 29/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0195 - accuracy: 0.9957 - val_loss: 4.3059 - val_accuracy: 0.5258
# Epoch 30/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0782 - accuracy: 0.9811 - val_loss: 5.7703 - val_accuracy: 0.3471
# Epoch 31/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.1474 - accuracy: 0.9647 - val_loss: 0.8749 - val_accuracy: 0.7491
# Epoch 32/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1194 - accuracy: 0.9655 - val_loss: 1.2362 - val_accuracy: 0.7148
# Epoch 33/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0618 - accuracy: 0.9819 - val_loss: 0.3262 - val_accuracy: 0.8900
# Epoch 34/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0743 - accuracy: 0.9802 - val_loss: 4.1317 - val_accuracy: 0.5876
# Epoch 35/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0546 - accuracy: 0.9845 - val_loss: 5.7017 - val_accuracy: 0.3883
# Epoch 36/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0752 - accuracy: 0.9759 - val_loss: 1.6689 - val_accuracy: 0.6942
# Epoch 37/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1272 - accuracy: 0.9647 - val_loss: 0.7818 - val_accuracy: 0.8351
# Epoch 38/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0507 - accuracy: 0.9828 - val_loss: 4.9459 - val_accuracy: 0.4192
# Epoch 39/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0560 - accuracy: 0.9785 - val_loss: 2.1850 - val_accuracy: 0.6186
# Epoch 40/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0313 - accuracy: 0.9905 - val_loss: 1.4220 - val_accuracy: 0.7216
# Epoch 41/50
# 1161/1161 [==============================] - 19s 16ms/step - loss: 0.0214 - accuracy: 0.9931 - val_loss: 0.3062 - val_accuracy: 0.9210
# Epoch 42/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.5741 - val_accuracy: 0.8351
# Epoch 43/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.3847 - val_accuracy: 0.9038
# Epoch 44/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0422 - accuracy: 0.9888 - val_loss: 2.1942 - val_accuracy: 0.6151
# Epoch 45/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.1029 - accuracy: 0.9724 - val_loss: 3.0725 - val_accuracy: 0.5808
# Epoch 46/50
# 1161/1161 [==============================] - 19s 17ms/step - loss: 0.0805 - accuracy: 0.9767 - val_loss: 2.7061 - val_accuracy: 0.5670
# Epoch 47/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0785 - accuracy: 0.9776 - val_loss: 0.6004 - val_accuracy: 0.8522
# Epoch 48/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0277 - accuracy: 0.9948 - val_loss: 0.3423 - val_accuracy: 0.9072
# Epoch 49/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0745 - accuracy: 0.9828 - val_loss: 0.9173 - val_accuracy: 0.8144
# Epoch 50/50
# 1161/1161 [==============================] - 20s 17ms/step - loss: 0.0402 - accuracy: 0.9905 - val_loss: 0.6289 - val_accuracy: 0.8385
# 291/291 [==============================] - 1s 2ms/step
# accuracy: 83.85%
# k =  2
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 83s 71ms/step - loss: 0.1436 - accuracy: 0.9596 - val_loss: 1.1072 - val_accuracy: 0.7448
# Epoch 2/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0533 - accuracy: 0.9836 - val_loss: 0.1024 - val_accuracy: 0.9655
# Epoch 3/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0777 - accuracy: 0.9750 - val_loss: 1.7069 - val_accuracy: 0.6621
# Epoch 4/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0470 - accuracy: 0.9862 - val_loss: 0.0398 - val_accuracy: 0.9862
# Epoch 5/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0136 - accuracy: 0.9974 - val_loss: 0.0069 - val_accuracy: 0.9966
# Epoch 6/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0456 - val_accuracy: 0.9897
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0438 - accuracy: 0.9880 - val_loss: 0.9159 - val_accuracy: 0.7759
# Epoch 8/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0688 - accuracy: 0.9836 - val_loss: 26.5009 - val_accuracy: 0.1138
# Epoch 9/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0685 - accuracy: 0.9828 - val_loss: 13.7236 - val_accuracy: 0.2034
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0818 - accuracy: 0.9785 - val_loss: 18.9120 - val_accuracy: 0.1759
# Epoch 11/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0973 - accuracy: 0.9768 - val_loss: 3.4053 - val_accuracy: 0.5897
# Epoch 12/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0605 - accuracy: 0.9828 - val_loss: 2.3869 - val_accuracy: 0.6828
# Epoch 13/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0698 - accuracy: 0.9785 - val_loss: 5.5412 - val_accuracy: 0.3793
# Epoch 14/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0308 - accuracy: 0.9905 - val_loss: 0.1559 - val_accuracy: 0.9483
# Epoch 15/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0479 - accuracy: 0.9888 - val_loss: 0.2396 - val_accuracy: 0.9414
# Epoch 16/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1178 - accuracy: 0.9673 - val_loss: 0.6691 - val_accuracy: 0.7966
# Epoch 17/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0422 - accuracy: 0.9897 - val_loss: 0.6961 - val_accuracy: 0.8414
# Epoch 18/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0863 - accuracy: 0.9750 - val_loss: 2.3232 - val_accuracy: 0.5931
# Epoch 19/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0280 - accuracy: 0.9914 - val_loss: 0.1739 - val_accuracy: 0.9276
# Epoch 20/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0137 - accuracy: 0.9948 - val_loss: 0.2506 - val_accuracy: 0.9379
# Epoch 21/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9759
# Epoch 22/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.0313 - val_accuracy: 0.9862
# Epoch 23/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 7.5323e-04 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 24/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 8.5608e-04 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 25/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.1160 - val_accuracy: 0.9586
# Epoch 26/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.2463 - val_accuracy: 0.9379
# Epoch 27/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0511 - accuracy: 0.9897 - val_loss: 0.8579 - val_accuracy: 0.7897
# Epoch 28/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0429 - accuracy: 0.9905 - val_loss: 2.0893 - val_accuracy: 0.6862
# Epoch 29/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0664 - accuracy: 0.9811 - val_loss: 2.2714 - val_accuracy: 0.6690
# Epoch 30/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.1131 - accuracy: 0.9647 - val_loss: 1.0227 - val_accuracy: 0.7517
# Epoch 31/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1059 - accuracy: 0.9759 - val_loss: 44.3657 - val_accuracy: 0.0690
# Epoch 32/50
# 1162/1162 [==============================] - 21s 18ms/step - loss: 0.0731 - accuracy: 0.9793 - val_loss: 22.2018 - val_accuracy: 0.1103
# Epoch 33/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0439 - accuracy: 0.9871 - val_loss: 2.9532 - val_accuracy: 0.6276
# Epoch 34/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0243 - accuracy: 0.9931 - val_loss: 0.1587 - val_accuracy: 0.9483
# Epoch 35/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.5258 - val_accuracy: 0.8759
# Epoch 36/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0331 - accuracy: 0.9931 - val_loss: 0.0954 - val_accuracy: 0.9724
# Epoch 37/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.0603 - val_accuracy: 0.9828
# Epoch 38/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0306 - val_accuracy: 0.9862
# Epoch 39/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 0.9862
# Epoch 40/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0022 - accuracy: 0.9983 - val_loss: 0.0299 - val_accuracy: 0.9862
# Epoch 41/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 5.4998e-04 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9897
# Epoch 42/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 0.2122 - val_accuracy: 0.9345
# Epoch 43/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0054 - accuracy: 0.9991 - val_loss: 0.0465 - val_accuracy: 0.9862
# Epoch 44/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0127 - accuracy: 0.9974 - val_loss: 0.4431 - val_accuracy: 0.9069
# Epoch 45/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0210 - accuracy: 0.9914 - val_loss: 0.7547 - val_accuracy: 0.8586
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1154 - accuracy: 0.9699 - val_loss: 10.4018 - val_accuracy: 0.3034
# Epoch 47/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.1477 - accuracy: 0.9664 - val_loss: 0.7964 - val_accuracy: 0.8241
# Epoch 48/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1735 - accuracy: 0.9544 - val_loss: 2.1819 - val_accuracy: 0.6310
# Epoch 49/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0403 - accuracy: 0.9914 - val_loss: 0.8437 - val_accuracy: 0.8276
# Epoch 50/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0158 - accuracy: 0.9966 - val_loss: 0.5353 - val_accuracy: 0.8621
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 86.21%
# k =  3
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 81s 70ms/step - loss: 0.0665 - accuracy: 0.9819 - val_loss: 1.9541 - val_accuracy: 0.6655
# Epoch 2/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0653 - accuracy: 0.9828 - val_loss: 0.5626 - val_accuracy: 0.8828
# Epoch 3/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0418 - accuracy: 0.9862 - val_loss: 0.2458 - val_accuracy: 0.9207
# Epoch 4/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0394 - accuracy: 0.9880 - val_loss: 0.3082 - val_accuracy: 0.8931
# Epoch 5/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0521 - accuracy: 0.9880 - val_loss: 2.4019 - val_accuracy: 0.6552
# Epoch 6/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0359 - accuracy: 0.9905 - val_loss: 0.7973 - val_accuracy: 0.8414
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0343 - accuracy: 0.9905 - val_loss: 0.4496 - val_accuracy: 0.9000
# Epoch 8/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0132 - accuracy: 0.9966 - val_loss: 0.0992 - val_accuracy: 0.9759
# Epoch 9/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0150 - val_accuracy: 0.9966
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0087 - accuracy: 0.9957 - val_loss: 0.0453 - val_accuracy: 0.9862
# Epoch 11/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.5336 - val_accuracy: 0.8828
# Epoch 12/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0171 - accuracy: 0.9957 - val_loss: 0.2301 - val_accuracy: 0.9483
# Epoch 13/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0267 - accuracy: 0.9914 - val_loss: 1.1410 - val_accuracy: 0.8793
# Epoch 14/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.1320 - accuracy: 0.9682 - val_loss: 4.5134 - val_accuracy: 0.4862
# Epoch 15/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0702 - accuracy: 0.9759 - val_loss: 0.8642 - val_accuracy: 0.7931
# Epoch 16/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0238 - accuracy: 0.9940 - val_loss: 0.1227 - val_accuracy: 0.9586
# Epoch 17/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0328 - accuracy: 0.9948 - val_loss: 0.1416 - val_accuracy: 0.9552
# Epoch 18/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0160 - accuracy: 0.9957 - val_loss: 0.0484 - val_accuracy: 0.9828
# Epoch 19/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0106 - accuracy: 0.9974 - val_loss: 0.0671 - val_accuracy: 0.9828
# Epoch 20/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0327 - accuracy: 0.9923 - val_loss: 0.2253 - val_accuracy: 0.9345
# Epoch 21/50
# 1162/1162 [==============================] - 21s 18ms/step - loss: 0.0667 - accuracy: 0.9845 - val_loss: 4.5854 - val_accuracy: 0.5690
# Epoch 22/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.1105 - accuracy: 0.9793 - val_loss: 2.9069 - val_accuracy: 0.6828
# Epoch 23/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0417 - accuracy: 0.9845 - val_loss: 1.9139 - val_accuracy: 0.7034
# Epoch 24/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0514 - accuracy: 0.9862 - val_loss: 0.5673 - val_accuracy: 0.8621
# Epoch 25/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0774 - accuracy: 0.9828 - val_loss: 0.2974 - val_accuracy: 0.9138
# Epoch 26/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0378 - accuracy: 0.9862 - val_loss: 0.5605 - val_accuracy: 0.8517
# Epoch 27/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0574 - accuracy: 0.9862 - val_loss: 0.4505 - val_accuracy: 0.8862
# Epoch 28/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0405 - accuracy: 0.9888 - val_loss: 1.5084 - val_accuracy: 0.7552
# Epoch 29/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0360 - accuracy: 0.9948 - val_loss: 0.0974 - val_accuracy: 0.9655
# Epoch 30/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0205 - val_accuracy: 0.9931
# Epoch 31/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0043 - accuracy: 0.9983 - val_loss: 0.0658 - val_accuracy: 0.9793
# Epoch 32/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0088 - accuracy: 0.9966 - val_loss: 0.0514 - val_accuracy: 0.9793
# Epoch 33/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9724
# Epoch 34/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 8.6385e-04 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 0.9897
# Epoch 35/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0245 - val_accuracy: 0.9966
# Epoch 36/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.0502 - val_accuracy: 0.9828
# Epoch 37/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0264 - accuracy: 0.9931 - val_loss: 0.3962 - val_accuracy: 0.8931
# Epoch 38/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0524 - accuracy: 0.9871 - val_loss: 1.5883 - val_accuracy: 0.7241
# Epoch 39/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0555 - accuracy: 0.9854 - val_loss: 2.2633 - val_accuracy: 0.6931
# Epoch 40/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0473 - accuracy: 0.9871 - val_loss: 5.3866 - val_accuracy: 0.5034
# Epoch 41/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0902 - accuracy: 0.9811 - val_loss: 1.0563 - val_accuracy: 0.8172
# Epoch 42/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0294 - accuracy: 0.9897 - val_loss: 4.5776 - val_accuracy: 0.5379
# Epoch 43/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0525 - accuracy: 0.9905 - val_loss: 0.4241 - val_accuracy: 0.9000
# Epoch 44/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0664 - accuracy: 0.9836 - val_loss: 1.9758 - val_accuracy: 0.7000
# Epoch 45/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0271 - accuracy: 0.9897 - val_loss: 0.7422 - val_accuracy: 0.8379
# Epoch 46/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0301 - accuracy: 0.9914 - val_loss: 0.0771 - val_accuracy: 0.9690
# Epoch 47/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0248 - accuracy: 0.9923 - val_loss: 0.4111 - val_accuracy: 0.9034
# Epoch 48/50
# 1162/1162 [==============================] - 20s 18ms/step - loss: 0.0225 - accuracy: 0.9940 - val_loss: 0.0993 - val_accuracy: 0.9690
# Epoch 49/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0059 - accuracy: 0.9966 - val_loss: 0.0611 - val_accuracy: 0.9724
# Epoch 50/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.1016 - val_accuracy: 0.9621
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 96.21%
# k =  4
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 83s 72ms/step - loss: 0.0787 - accuracy: 0.9854 - val_loss: 0.4845 - val_accuracy: 0.9069
# Epoch 2/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0496 - accuracy: 0.9880 - val_loss: 0.1811 - val_accuracy: 0.9517
# Epoch 3/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0230 - accuracy: 0.9914 - val_loss: 0.0885 - val_accuracy: 0.9793
# Epoch 4/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0284 - accuracy: 0.9914 - val_loss: 0.0363 - val_accuracy: 0.9931
# Epoch 5/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0300 - accuracy: 0.9897 - val_loss: 0.0596 - val_accuracy: 0.9690
# Epoch 6/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0187 - accuracy: 0.9923 - val_loss: 0.0232 - val_accuracy: 0.9931
# Epoch 7/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0130 - accuracy: 0.9974 - val_loss: 0.0102 - val_accuracy: 0.9931
# Epoch 8/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0380 - accuracy: 0.9888 - val_loss: 0.0453 - val_accuracy: 0.9862
# Epoch 9/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0588 - accuracy: 0.9871 - val_loss: 1.4080 - val_accuracy: 0.8034
# Epoch 10/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0538 - accuracy: 0.9871 - val_loss: 0.4298 - val_accuracy: 0.9138
# Epoch 11/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0775 - accuracy: 0.9802 - val_loss: 1.4457 - val_accuracy: 0.7241
# Epoch 12/50
# 1162/1162 [==============================] - 20s 17ms/step - loss: 0.0262 - accuracy: 0.9923 - val_loss: 0.7337 - val_accuracy: 0.8241
# Epoch 13/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.1130 - val_accuracy: 0.9448
# Epoch 14/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 15/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0172 - accuracy: 0.9957 - val_loss: 0.0364 - val_accuracy: 0.9793
# Epoch 16/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0222 - accuracy: 0.9940 - val_loss: 0.1099 - val_accuracy: 0.9690
# Epoch 17/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0451 - accuracy: 0.9948 - val_loss: 0.1159 - val_accuracy: 0.9690
# Epoch 18/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0145 - accuracy: 0.9966 - val_loss: 0.0452 - val_accuracy: 0.9759
# Epoch 19/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0205 - accuracy: 0.9974 - val_loss: 0.0160 - val_accuracy: 0.9897
# Epoch 20/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.4417 - val_accuracy: 0.9172
# Epoch 21/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0303 - val_accuracy: 0.9897
# Epoch 22/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0280 - accuracy: 0.9966 - val_loss: 2.5975 - val_accuracy: 0.6310
# Epoch 23/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0143 - accuracy: 0.9957 - val_loss: 0.0254 - val_accuracy: 0.9931
# Epoch 24/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 3.6453e-04 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 25/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 26/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0032 - accuracy: 0.9983 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 27/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0069 - accuracy: 0.9991 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 28/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0404 - accuracy: 0.9888 - val_loss: 8.5182 - val_accuracy: 0.3103
# Epoch 29/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0490 - accuracy: 0.9862 - val_loss: 0.0845 - val_accuracy: 0.9759
# Epoch 30/50
# 1162/1162 [==============================] - 17s 15ms/step - loss: 0.0376 - accuracy: 0.9914 - val_loss: 0.1208 - val_accuracy: 0.9448
# Epoch 31/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0435 - accuracy: 0.9897 - val_loss: 1.4886 - val_accuracy: 0.7931
# Epoch 32/50
# 1162/1162 [==============================] - 17s 15ms/step - loss: 0.0164 - accuracy: 0.9931 - val_loss: 0.0727 - val_accuracy: 0.9759
# Epoch 33/50
# 1162/1162 [==============================] - 17s 15ms/step - loss: 0.0052 - accuracy: 0.9974 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 34/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0108 - accuracy: 0.9974 - val_loss: 0.2178 - val_accuracy: 0.9552
# Epoch 35/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 9.6946e-04 - val_accuracy: 1.0000
# Epoch 36/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 37/50
# 1162/1162 [==============================] - 19s 17ms/step - loss: 0.0104 - accuracy: 0.9948 - val_loss: 0.0881 - val_accuracy: 0.9793
# Epoch 38/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9966
# Epoch 39/50
# 1162/1162 [==============================] - 23s 20ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.0931 - val_accuracy: 0.9724
# Epoch 40/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0219 - accuracy: 0.9931 - val_loss: 0.7898 - val_accuracy: 0.8862
# Epoch 41/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0063 - accuracy: 0.9991 - val_loss: 0.0891 - val_accuracy: 0.9828
# Epoch 42/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0392 - accuracy: 0.9871 - val_loss: 4.6834 - val_accuracy: 0.4690
# Epoch 43/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.1061 - accuracy: 0.9656 - val_loss: 3.3965 - val_accuracy: 0.6379
# Epoch 44/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.1159 - accuracy: 0.9733 - val_loss: 2.1019 - val_accuracy: 0.6483
# Epoch 45/50
# 1162/1162 [==============================] - 18s 16ms/step - loss: 0.0690 - accuracy: 0.9854 - val_loss: 0.2518 - val_accuracy: 0.9345
# Epoch 46/50
# 1162/1162 [==============================] - 18s 15ms/step - loss: 0.0116 - accuracy: 0.9948 - val_loss: 1.0169 - val_accuracy: 0.8345
# Epoch 47/50
# 1162/1162 [==============================] - 17s 15ms/step - loss: 0.0068 - accuracy: 0.9957 - val_loss: 0.1346 - val_accuracy: 0.9621
# Epoch 48/50
# 1162/1162 [==============================] - 23s 20ms/step - loss: 0.0502 - accuracy: 0.9880 - val_loss: 2.3709 - val_accuracy: 0.6586
# Epoch 49/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0270 - accuracy: 0.9923 - val_loss: 0.2495 - val_accuracy: 0.9448
# Epoch 50/50
# 1162/1162 [==============================] - 19s 16ms/step - loss: 0.0427 - accuracy: 0.9854 - val_loss: 4.0973 - val_accuracy: 0.5793
# 290/290 [==============================] - 1s 2ms/step
# accuracy: 57.93%
# 79.13% (+/- 13.21%)
# CPU times: user 1h 46min 57s, sys: 9min 17s, total: 1h 56min 14s
# Wall time: 1h 33min 26s

# %%
# summarize history for accuracy
filename = '/content/drive/My Drive/Notebook/Training_Files/history_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_DenseNet_'+str(dtype)+'_f'+str(f)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.36      0.53        11
#            1       0.88      1.00      0.94        15
#            2       0.86      1.00      0.93        25
#            3       0.94      0.79      0.86        19
#            4       0.96      0.96      0.96        23
#            5       0.73      0.79      0.76        24
#            6       0.84      0.76      0.80        21
#            7       1.00      1.00      1.00         2
#            8       0.67      1.00      0.80         2
#            9       0.67      1.00      0.80         2
#           10       1.00      1.00      1.00         3
#           11       1.00      0.62      0.77         8
#           12       1.00      1.00      1.00        16
#           13       0.92      1.00      0.96        11
#           14       1.00      0.91      0.95        11
#           15       1.00      1.00      1.00        11
#           16       1.00      1.00      1.00         5
#           17       0.73      0.92      0.81        12
#           18       1.00      0.70      0.82        10
#           19       0.82      0.90      0.86        10
#           20       0.75      0.55      0.63        11
#           21       0.86      1.00      0.92        12
#           22       0.78      1.00      0.88        18
#           23       0.73      0.79      0.76        24
#           24       0.78      0.82      0.80        17
#           25       1.00      0.67      0.80         3
#           26       0.70      0.78      0.74         9
#           27       1.00      0.89      0.94        28
#
#     accuracy                           0.86       363
#    macro avg       0.88      0.86      0.86       363
# weighted avg       0.87      0.86      0.86       363
