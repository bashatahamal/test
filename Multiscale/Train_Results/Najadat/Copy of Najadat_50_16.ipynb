# %% [markdown]
# ### **INIT**

# %%
# %%capture
# !pip install q tensorflow==2.1
# !pip install q keras==2.3.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
import pickle
import matplotlib.pyplot as plt
import random
import itertools
saved_output = []

def plot_gallery(images, titles, n_row=3, n_col=4):
    plt.figure(1, figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        r = random.randint(1,len(images))
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[r], cmap=plt.cm.gray)
        plt.title(char_list_nameonly[titles[r]], size=12)
        plt.xticks(())
        plt.yticks(())
    plt.show()
    #plt.savefig("predict.png")

def plot_gallery_norand(images, titles, n_row=3, n_col=4):
    plt.figure(1, figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
#         r = random.randint(1,len(images))
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[i], cmap=plt.cm.gray)
        plt.title(char_list_nameonly[titles[i]], size=12)
        plt.xticks(())
        plt.yticks(())
    plt.show()

def plot_gallery_predict(images, predict, true, n_row=3, n_col=4):
    plt.figure(1, figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)
    for i in range(n_row * n_col):
        r = random.randint(1,len(images))
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[r], cmap=plt.cm.gray)
        plt.title('p:' + str(predict[r]) + '   t:' + str(true[r]), size=12)
        plt.xticks(())
        plt.yticks(())
    plt.show()
    #plt.savefig("predict.png")

# %%
loc_collection = '/content/drive/My Drive/Notebook/Auto_Collection_Gray/'
shape = 'Square'
# shape = 'No_Margin'
char_list_nameonly = [
    'Alif‬', 'Bā’', 'Tā’', 'Ṡā’‬', 'Jīm', 'Ḥā’‬', 'Khā’‬',
    'Dāl‬', 'Żāl‬', 'Rā’‬', 'zai‬', 'sīn‬', 'syīn‬', 'ṣād',
    'ḍād', 'ṭā’‬', 'ẓȧ’‬', '‘ain', 'gain‬', 'fā’‬', 'qāf‬',
    'kāf‬', 'lām‬', 'mīm‬', 'nūn‬', 'wāw‬', 'hā’‬', 'yā’‬'
]
import pickle
filename = '/content/drive/My Drive/Notebook/sameratio_keepform.pkl'
sameratio_keepform = pickle.load(open(filename, 'rb'))
filename = '/content/drive/My Drive/Notebook/diffratio_keepform.pkl'
diffratio_keepform = pickle.load(open(filename, 'rb'))
filename = '/content/drive/My Drive/Notebook/sameratio_diffform.pkl'
sameratio_diffform = pickle.load(open(filename, 'rb'))
filename = '/content/drive/My Drive/Notebook/diffratio_diffform.pkl'
diffratio_diffform = pickle.load(open(filename, 'rb'))

print(sameratio_keepform.keys())
print(diffratio_keepform.keys())
print(sameratio_diffform.keys())
print(diffratio_diffform.keys())
# Out:
# dict_keys(['sk_32_bh', 'sk_32_bw', 'sk_sibh', 'sk_sibw', 'sk_largest'])
# dict_keys(['dk_32', 'dk_sibh', 'dk_sibw', 'dk_libh', 'dk_libw'])
# dict_keys(['sd_32', 'sd_smallest', 'sd_largest'])
# dict_keys(['dd_32', 'dd_sibh', 'dd_sibw', 'dd_libh', 'dd_libw'])

# %%
data_dk = []
label_dk = []
for i in range(0,28):
    for x in range(len(diffratio_keepform['dk_32'][i])):
        gd = diffratio_keepform['dk_32'][i][x]
        data_dk.append(diffratio_keepform['dk_32'][i][x])
        label_dk.append(i)
data_dk = np.array(data_dk)
label_dk = np.array(label_dk)

data_sk = []
data_sk_temp = []
label_sk = []
for i in range(0,28):
    for x in range(len(sameratio_keepform['sk_32_bh'][i])):
        data_sk_temp.append(sameratio_keepform['sk_32_bh'][i][x])
        label_sk.append(i)
for x in range(len(data_sk_temp)):
    h, w = data_sk_temp[x].shape
    if h and w > 32:
        img = cv2.resize(data_sk_temp[x], (32, 32))
        print(x)
    else:
        img = data_sk_temp[x]
    y = list(img.ravel())
    y = np.array(y)
    data_sk.append(y.reshape(32, 32))
data_sk = np.array(data_sk)
label_sk = np.array(label_sk)

data_sd = []
label_sd = []
for i in range(0,28):
    for x in range(len(sameratio_diffform['sd_largest'][i])):
        data_sd.append(sameratio_diffform['sd_largest'][i][x])
        label_sd.append(i)
data_sd = np.array(data_sd)
label_sd = np.array(label_sd)
data_sd_32 = []
for data in data_sd:
  data_sd_32.append(cv2.resize(data, (32,32)))
data_sd_32 = np.array(data_sd_32)
data_sd = data_sd_32

data_dd = []
label_dd = []
for i in range(0,28):
    for x in range(len(diffratio_diffform['dd_32'][i])):
        data_dd.append(diffratio_diffform['dd_32'][i][x])
        label_dd.append(i)
data_dd = np.array(data_dd)
label_dd = np.array(label_dd)
# Out:
# 1311

# %%
print('sameratio_keepform')
plot_gallery_norand(data_sk, label_sk, 1, 4)
print('diffratio_keepform')
plot_gallery_norand(data_dk, label_dk, 1, 4)
print('sameratio_diffform')
plot_gallery_norand(data_sd, label_sd, 1, 4)
print('diffratio_diffform')
plot_gallery_norand(data_dd, label_dd, 1, 4)
# Out:
# sameratio_keepform
# diffratio_keepform
# sameratio_diffform
# diffratio_diffform

# %% [markdown]
# ### **Data**

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42

dtype = 'DD'
data_train, data_test, y_train, y_test = train_test_split(
data_dd, label_dd, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %% [markdown]
# ### **Model**

# %%
from sklearn.model_selection import StratifiedKFold
from keras.utils.np_utils import to_categorical
import keras
import keras.backend as K
from keras.models import Sequential
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization, MaxPooling2D
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU, AveragePooling2D
import numpy
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

from time import time
import numpy as np

# %%
def Najadat(n_classes):
  model = Sequential()
  # Conv1
  model.add(Conv2D(filters = 16,
                    kernel_size = 5,
                    activation = 'relu', 
                    input_shape = (32,32,1)))
  # Conv2
  model.add(Conv2D(filters = 16,
                    kernel_size = 5,
                    activation = 'relu'))
  # Pool1
  model.add(MaxPooling2D(pool_size = 2, strides = 2))
  # Conv3
  model.add(Conv2D(filters = 32,
                    kernel_size = 5,
                    activation = 'relu', 
                    input_shape = (32,32,1)))
  # Conv4
  model.add(Conv2D(filters = 32,
                    kernel_size = 5,
                    activation = 'relu', 
                    input_shape = (32,32,1)))
  # Pool2
  model.add(MaxPooling2D(pool_size = 2, strides = 2))
  # 3FC
  model.add(Flatten())
  model.add(Dense(units = 64, 
                  activation = 'relu',
                  kernel_regularizer='l2'))
  model.add(Dropout(0.1))
  model.add(BatchNormalization())
  model.add(Dense(units = 32, 
                  activation = 'relu',
                  kernel_regularizer='l2'))
  model.add(Dropout(0.1))
  model.add(BatchNormalization())
  #Output Layer
  model.add(Dense(units = 28, activation = 'softmax'))

  # Compile model
  model.compile(optimizer = 'Adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

  return model

# %%
# %%time
n_classes = 28
ep = 50
bs = 16

K.clear_session()
model = Najadat(n_classes)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 16)        6416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 32)          12832
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 32)          25632
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 28)                924
# =================================================================
# Total params: 56,940
# Trainable params: 56,748
# Non-trainable params: 192
# _________________________________________________________________
# CPU times: user 379 ms, sys: 8.06 ms, total: 387 ms
# Wall time: 380 ms

# %%
# %%time
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    # model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('Najadat')
    filename = '/content/drive/My Drive/Notebook/Training_Files/Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 1s 1ms/step - loss: 4.5809 - accuracy: 0.0715 - val_loss: 4.1964 - val_accuracy: 0.0619
# Epoch 2/50
# 1161/1161 [==============================] - 1s 504us/step - loss: 3.8654 - accuracy: 0.1421 - val_loss: 3.9429 - val_accuracy: 0.0619
# Epoch 3/50
# 1161/1161 [==============================] - 1s 510us/step - loss: 3.3366 - accuracy: 0.2455 - val_loss: 3.6190 - val_accuracy: 0.2577
# Epoch 4/50
# 1161/1161 [==============================] - 1s 501us/step - loss: 2.9292 - accuracy: 0.3351 - val_loss: 3.3395 - val_accuracy: 0.2577
# Epoch 5/50
# 1161/1161 [==============================] - 1s 489us/step - loss: 2.6179 - accuracy: 0.4065 - val_loss: 3.1164 - val_accuracy: 0.3093
# Epoch 6/50
# 1161/1161 [==============================] - 1s 495us/step - loss: 2.3609 - accuracy: 0.4755 - val_loss: 2.7316 - val_accuracy: 0.4261
# Epoch 7/50
# 1161/1161 [==============================] - 1s 490us/step - loss: 2.1652 - accuracy: 0.5134 - val_loss: 2.6085 - val_accuracy: 0.4021
# Epoch 8/50
# 1161/1161 [==============================] - 1s 494us/step - loss: 1.9030 - accuracy: 0.5814 - val_loss: 2.1868 - val_accuracy: 0.5464
# Epoch 9/50
# 1161/1161 [==============================] - 1s 494us/step - loss: 1.6891 - accuracy: 0.6245 - val_loss: 1.8302 - val_accuracy: 0.5911
# Epoch 10/50
# 1161/1161 [==============================] - 1s 493us/step - loss: 1.4734 - accuracy: 0.6865 - val_loss: 1.6178 - val_accuracy: 0.6323
# Epoch 11/50
# 1161/1161 [==============================] - 1s 509us/step - loss: 1.3618 - accuracy: 0.7046 - val_loss: 1.6056 - val_accuracy: 0.6598
# Epoch 12/50
# 1161/1161 [==============================] - 1s 502us/step - loss: 1.2501 - accuracy: 0.7347 - val_loss: 1.3579 - val_accuracy: 0.7079
# Epoch 13/50
# 1162/1162 [==============================] - 1s 513us/step - loss: 0.1137 - accuracy: 0.9923 - val_loss: 0.1891 - val_accuracy: 0.9793
# Epoch 42/50
# 1162/1162 [==============================] - 1s 475us/step - loss: 0.1261 - accuracy: 0.9862 - val_loss: 0.2233 - val_accuracy: 0.9759
# Epoch 43/50
# 1162/1162 [==============================] - 1s 477us/step - loss: 0.1290 - accuracy: 0.9871 - val_loss: 0.2155 - val_accuracy: 0.9690
# Epoch 44/50
# 1162/1162 [==============================] - 1s 511us/step - loss: 0.1416 - accuracy: 0.9871 - val_loss: 0.1546 - val_accuracy: 0.9862
# Epoch 45/50
# 1162/1162 [==============================] - 1s 491us/step - loss: 0.1323 - accuracy: 0.9880 - val_loss: 0.1268 - val_accuracy: 0.9931
# Epoch 46/50
# 1162/1162 [==============================] - 1s 497us/step - loss: 0.1108 - accuracy: 0.9923 - val_loss: 0.1714 - val_accuracy: 0.9724
# Epoch 47/50
# 1162/1162 [==============================] - 1s 496us/step - loss: 0.1097 - accuracy: 0.9905 - val_loss: 0.1463 - val_accuracy: 0.9862
# Epoch 48/50
# 1162/1162 [==============================] - 1s 495us/step - loss: 0.1119 - accuracy: 0.9888 - val_loss: 0.1274 - val_accuracy: 0.9828
# Epoch 49/50
# 1162/1162 [==============================] - 1s 495us/step - loss: 0.1116 - accuracy: 0.9923 - val_loss: 0.1568 - val_accuracy: 0.9724
# Epoch 50/50
# 1162/1162 [==============================] - 1s 491us/step - loss: 0.1238 - accuracy: 0.9871 - val_loss: 0.1246 - val_accuracy: 0.9931
# 290/290 [==============================] - 0s 86us/step
# accuracy: 99.31%
# 94.70% (+/- 5.00%)
# CPU times: user 3min, sys: 17.3 s, total: 3min 17s
# Wall time: 2min 23s

# %% [markdown]
# ### **Result**

# %%
# summarize history for accuracy
filename = '/content/drive/My Drive/Notebook/Training_Files/history_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79        11
#            1       0.86      0.80      0.83        15
#            2       0.85      0.92      0.88        25
#            3       0.68      0.89      0.77        19
#            4       0.84      0.91      0.87        23
#            5       0.94      0.67      0.78        24
#            6       0.64      0.86      0.73        21
#            7       0.33      1.00      0.50         2
#            8       1.00      0.50      0.67         2
#            9       0.67      1.00      0.80         2
#           10       0.75      1.00      0.86         3
#           11       0.80      1.00      0.89         8
#           12       0.92      0.75      0.83        16
#           13       0.83      0.91      0.87        11
#           14       1.00      0.73      0.84        11
#           15       0.82      0.82      0.82        11
#           16       1.00      0.80      0.89         5
#           17       1.00      0.50      0.67        12
#           18       0.69      0.90      0.78        10
#           19       0.83      1.00      0.91        10
#           20       1.00      0.91      0.95        11
#           21       0.83      0.83      0.83        12
#           22       0.68      0.72      0.70        18
#           23       0.88      0.62      0.73        24
#           24       0.87      0.76      0.81        17
#           25       1.00      1.00      1.00         3
#           26       1.00      0.89      0.94         9
#           27       1.00      0.82      0.90        28
#
#     accuracy                           0.82       363
#    macro avg       0.83      0.84      0.82       363
# weighted avg       0.85      0.82      0.82       363

# %% [markdown]
# ### **Next DK**

# %%
# %reset_selective -f data_train
# %reset_selective -f data_test
# %reset_selective -f y_train
# %reset_selective -f y_test
# %reset_selective -f loaded_train
# %reset_selective -f loaded_test
# %reset_selective -f model
sns.reset_orig()

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42
dtype = 'DK'
data_train, data_test, y_train, y_test = train_test_split(
data_dk, label_dk, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %%
# %%time
K.clear_session()
model = Najadat(n_classes)
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    # model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('Najadat')
    filename = '/content/drive/My Drive/Notebook/Training_Files/Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 1s 1ms/step - loss: 4.6621 - accuracy: 0.0543 - val_loss: 4.2460 - val_accuracy: 0.0619
# Epoch 2/50
# 1161/1161 [==============================] - 1s 500us/step - loss: 3.8819 - accuracy: 0.1473 - val_loss: 4.0116 - val_accuracy: 0.0790
# Epoch 3/50
# 1161/1161 [==============================] - 1s 531us/step - loss: 3.3618 - accuracy: 0.2679 - val_loss: 3.7138 - val_accuracy: 0.1340
# Epoch 4/50
# 1161/1161 [==============================] - 1s 500us/step - loss: 2.9256 - accuracy: 0.3600 - val_loss: 3.5030 - val_accuracy: 0.1890
# Epoch 5/50
# 1161/1161 [==============================] - 1s 497us/step - loss: 2.5691 - accuracy: 0.4668 - val_loss: 3.0331 - val_accuracy: 0.4021
# Epoch 6/50
# 1161/1161 [==============================] - 1s 514us/step - loss: 2.2891 - accuracy: 0.5082 - val_loss: 2.8573 - val_accuracy: 0.4055
# Epoch 7/50
# 1161/1161 [==============================] - 1s 512us/step - loss: 2.0136 - accuracy: 0.5762 - val_loss: 2.4630 - val_accuracy: 0.4845
# Epoch 8/50
# 1161/1161 [==============================] - 1s 512us/step - loss: 1.7530 - accuracy: 0.6279 - val_loss: 1.8281 - val_accuracy: 0.6770
# Epoch 9/50
# 1161/1161 [==============================] - 1s 503us/step - loss: 1.5392 - accuracy: 0.7046 - val_loss: 1.7730 - val_accuracy: 0.6667
# Epoch 10/50
# 1161/1161 [==============================] - 1s 516us/step - loss: 1.3874 - accuracy: 0.7468 - val_loss: 1.5055 - val_accuracy: 0.7251
# Epoch 11/50
# 1161/1161 [==============================] - 1s 547us/step - loss: 1.2287 - accuracy: 0.7717 - val_loss: 1.4668 - val_accuracy: 0.6976
# Epoch 12/50
# 1161/1161 [==============================] - 1s 525us/step - loss: 1.0565 - accuracy: 0.8096 - val_loss: 1.3352 - val_accuracy: 0.7251
# Epoch 13/50
# 1161/1161 [==============================] - 1s 554us/step - loss: 0.9672 - accuracy: 0.8389 - val_loss: 1.2338 - val_accuracy: 0.7388
# Epoch 14/50
# 1161/1161 [==============================] - 1s 524us/step - loss: 0.9224 - accuracy: 0.8562 - val_loss: 1.2435 - val_accuracy: 0.7285
# 1162/1162 [==============================] - 1s 467us/step - loss: 0.1270 - accuracy: 0.9880 - val_loss: 0.0970 - val_accuracy: 0.9966
# Epoch 44/50
# 1162/1162 [==============================] - 1s 475us/step - loss: 0.1057 - accuracy: 0.9948 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 45/50
# 1162/1162 [==============================] - 1s 490us/step - loss: 0.1027 - accuracy: 0.9948 - val_loss: 0.1525 - val_accuracy: 0.9862
# Epoch 46/50
# 1162/1162 [==============================] - 1s 482us/step - loss: 0.1161 - accuracy: 0.9905 - val_loss: 0.1112 - val_accuracy: 0.9931
# Epoch 47/50
# 1162/1162 [==============================] - 1s 462us/step - loss: 0.1835 - accuracy: 0.9725 - val_loss: 0.1079 - val_accuracy: 0.9897
# Epoch 48/50
# 1162/1162 [==============================] - 1s 463us/step - loss: 0.1761 - accuracy: 0.9759 - val_loss: 0.1288 - val_accuracy: 0.9862
# Epoch 49/50
# 1162/1162 [==============================] - 1s 463us/step - loss: 0.1328 - accuracy: 0.9871 - val_loss: 0.1093 - val_accuracy: 0.9862
# Epoch 50/50
# 1162/1162 [==============================] - 1s 481us/step - loss: 0.1336 - accuracy: 0.9854 - val_loss: 0.1534 - val_accuracy: 0.9793
# 290/290 [==============================] - 0s 85us/step
# accuracy: 97.93%
# 93.95% (+/- 4.80%)
# CPU times: user 2min 58s, sys: 17.1 s, total: 3min 15s
# Wall time: 2min 23s

# %%
# summarize history for accuracy
filename = '/content/drive/My Drive/Notebook/Training_Files/history_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.59      0.87      0.70        15
#            2       0.93      1.00      0.96        25
#            3       0.89      0.84      0.86        19
#            4       0.85      1.00      0.92        23
#            5       0.89      0.67      0.76        24
#            6       0.75      0.86      0.80        21
#            7       0.67      1.00      0.80         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         3
#           11       1.00      0.88      0.93         8
#           12       1.00      0.88      0.93        16
#           13       0.85      1.00      0.92        11
#           14       1.00      0.82      0.90        11
#           15       1.00      0.82      0.90        11
#           16       1.00      1.00      1.00         5
#           17       0.67      0.50      0.57        12
#           18       0.80      0.80      0.80        10
#           19       0.83      1.00      0.91        10
#           20       1.00      0.82      0.90        11
#           21       1.00      0.75      0.86        12
#           22       0.86      1.00      0.92        18
#           23       0.87      0.83      0.85        24
#           24       0.74      1.00      0.85        17
#           25       1.00      1.00      1.00         3
#           26       1.00      0.89      0.94         9
#           27       1.00      0.79      0.88        28
#
#     accuracy                           0.87       363
#    macro avg       0.90      0.89      0.89       363
# weighted avg       0.89      0.87      0.87       363

# %% [markdown]
# ### **Next SK**

# %%
# %reset_selective -f data_train
# %reset_selective -f data_test
# %reset_selective -f y_train
# %reset_selective -f y_test
# %reset_selective -f loaded_train
# %reset_selective -f loaded_test
# %reset_selective -f model
sns.reset_orig()

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42
dtype = 'SK'
data_train, data_test, y_train, y_test = train_test_split(
data_sk, label_sk, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %%
# %%time
K.clear_session() 
model = Najadat(n_classes)
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    # model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('Najadat')
    filename = '/content/drive/My Drive/Notebook/Training_Files/Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 1s 978us/step - loss: 4.5223 - accuracy: 0.0655 - val_loss: 4.1887 - val_accuracy: 0.0584
# Epoch 2/50
# 1161/1161 [==============================] - 1s 471us/step - loss: 3.7388 - accuracy: 0.1576 - val_loss: 3.9334 - val_accuracy: 0.1581
# Epoch 3/50
# 1161/1161 [==============================] - 1s 490us/step - loss: 3.2274 - accuracy: 0.2687 - val_loss: 3.7203 - val_accuracy: 0.2302
# Epoch 4/50
# 1161/1161 [==============================] - 1s 467us/step - loss: 2.8443 - accuracy: 0.3575 - val_loss: 3.4816 - val_accuracy: 0.2784
# Epoch 5/50
# 1161/1161 [==============================] - 1s 496us/step - loss: 2.5150 - accuracy: 0.4513 - val_loss: 3.1144 - val_accuracy: 0.3333
# Epoch 6/50
# 1161/1161 [==============================] - 1s 472us/step - loss: 2.2071 - accuracy: 0.5254 - val_loss: 2.5638 - val_accuracy: 0.5086
# Epoch 7/50
# 1161/1161 [==============================] - 1s 504us/step - loss: 1.9196 - accuracy: 0.5986 - val_loss: 2.4075 - val_accuracy: 0.4914
# Epoch 8/50
# 1161/1161 [==============================] - 1s 470us/step - loss: 1.7114 - accuracy: 0.6451 - val_loss: 2.1874 - val_accuracy: 0.5395
# Epoch 9/50
# 1161/1161 [==============================] - 1s 480us/step - loss: 1.5010 - accuracy: 0.7080 - val_loss: 1.9570 - val_accuracy: 0.5361
# Epoch 10/50
# 1161/1161 [==============================] - 1s 485us/step - loss: 1.3522 - accuracy: 0.7459 - val_loss: 1.6254 - val_accuracy: 0.6495
# Epoch 11/50
# 1161/1161 [==============================] - 1s 491us/step - loss: 1.1701 - accuracy: 0.7864 - val_loss: 1.7107 - val_accuracy: 0.6014
# Epoch 12/50
# 1161/1161 [==============================] - 1s 471us/step - loss: 1.0160 - accuracy: 0.8165 - val_loss: 1.5857 - val_accuracy: 0.6082
# Epoch 13/50
# 1161/1161 [==============================] - 1s 531us/step - loss: 0.9114 - accuracy: 0.8596 - val_loss: 1.3160 - val_accuracy: 0.6701
# Epoch 14/50
# 1161/1161 [==============================] - 1s 497us/step - loss: 0.8309 - accuracy: 0.8665 - val_loss: 1.4937 - val_accuracy: 0.6598
# Epoch 15/50
# 1161/1161 [==============================] - 1s 495us/step - loss: 0.7420 - accuracy: 0.8949 - val_loss: 1.2834 - val_accuracy: 0.7045
# Epoch 16/50
# 1161/1161 [==============================] - 1s 494us/step - loss: 0.6988 - accuracy: 0.9027 - val_loss: 1.3865 - val_accuracy: 0.6254
# 1162/1162 [==============================] - 1s 466us/step - loss: 0.0887 - accuracy: 0.9940 - val_loss: 0.1067 - val_accuracy: 0.9897
# Epoch 46/50
# 1162/1162 [==============================] - 1s 476us/step - loss: 0.0818 - accuracy: 0.9931 - val_loss: 0.0973 - val_accuracy: 0.9966
# Epoch 47/50
# 1162/1162 [==============================] - 1s 465us/step - loss: 0.0984 - accuracy: 0.9880 - val_loss: 0.1405 - val_accuracy: 0.9759
# Epoch 48/50
# 1162/1162 [==============================] - 1s 470us/step - loss: 0.0864 - accuracy: 0.9914 - val_loss: 0.1249 - val_accuracy: 0.9862
# Epoch 49/50
# 1162/1162 [==============================] - 1s 466us/step - loss: 0.1087 - accuracy: 0.9845 - val_loss: 0.2223 - val_accuracy: 0.9552
# Epoch 50/50
# 1162/1162 [==============================] - 1s 468us/step - loss: 0.1483 - accuracy: 0.9725 - val_loss: 0.1846 - val_accuracy: 0.9724
# 290/290 [==============================] - 0s 91us/step
# accuracy: 97.24%
# 91.54% (+/- 8.31%)
# CPU times: user 2min 58s, sys: 17.8 s, total: 3min 16s
# Wall time: 2min 22s

# %%
# summarize history for accuracy
filename = '/content/drive/My Drive/Notebook/Training_Files/history_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        11
#            1       0.68      0.87      0.76        15
#            2       0.81      0.88      0.85        25
#            3       1.00      0.79      0.88        19
#            4       0.95      0.87      0.91        23
#            5       0.86      0.79      0.83        24
#            6       0.85      0.81      0.83        21
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         2
#            9       1.00      0.50      0.67         2
#           10       1.00      1.00      1.00         3
#           11       0.62      1.00      0.76         8
#           12       1.00      1.00      1.00        16
#           13       0.85      1.00      0.92        11
#           14       0.82      0.82      0.82        11
#           15       0.82      0.82      0.82        11
#           16       1.00      1.00      1.00         5
#           17       0.89      0.67      0.76        12
#           18       0.78      0.70      0.74        10
#           19       0.77      1.00      0.87        10
#           20       1.00      0.73      0.84        11
#           21       0.79      0.92      0.85        12
#           22       0.89      0.89      0.89        18
#           23       0.94      0.67      0.78        24
#           24       0.64      0.94      0.76        17
#           25       1.00      1.00      1.00         3
#           26       0.58      0.78      0.67         9
#           27       0.96      0.79      0.86        28
#
#     accuracy                           0.84       363
#    macro avg       0.87      0.86      0.85       363
# weighted avg       0.86      0.84      0.84       363

# %% [markdown]
# ### **Next SD**

# %%
# %reset_selective -f data_train
# %reset_selective -f data_test
# %reset_selective -f y_train
# %reset_selective -f y_test
# %reset_selective -f loaded_train
# %reset_selective -f loaded_test
# %reset_selective -f model
sns.reset_orig()

# %%
from sklearn.model_selection import train_test_split
test_size = 0.20
random_state = 42
dtype = 'SD'
data_train, data_test, y_train, y_test = train_test_split(
data_sd, label_sd, test_size=test_size,random_state=random_state)
train = {}
train['image'] = data_train
train['label'] = y_train
test = {}
test['image'] = data_test
test['label'] = y_test

filename = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
pickle.dump(train, open(filename, 'wb'))
filename = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'
pickle.dump(test, open(filename, 'wb'))
print(data_train.shape)
print(y_train.shape)
plot_gallery(data_train, y_train, 1,5)
# Out:
# (1452, 32, 32)
# (1452,)

# %%
filename_train = '/content/drive/My Drive/Notebook/Training_Files/train_dataset.pkl'
filename_test = '/content/drive/My Drive/Notebook/Training_Files/test_dataset.pkl'

loaded_train = pickle.load(open(filename_train, 'rb'))
loaded_test = pickle.load(open(filename_test, 'rb'))

# %%
print('Training Data', len(loaded_train['image']))
plot_gallery(loaded_train['image'], loaded_train['label'], 1, 5)
print('Testing Data', len(loaded_test['image']))
plot_gallery(loaded_test['image'], loaded_train['label'], 1, 5)
# Out:
# Training Data 1452
# Testing Data 363

# %%
data_train = loaded_train['image']
data_train = data_train.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_train = loaded_train['label']

data_test = loaded_test['image']
data_test = data_test.reshape(-1, 32, 32, 1).astype(np.float32)/255
y_test = loaded_test['label']

# %%
# %%time
K.clear_session() 
model = Najadat(n_classes)
# earlystopper = EarlyStopping(monitor='val_loss',
#                              patience=10, verbose=1, mode='auto')
seed = 7
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
X = data_train
Y = y_train
cvscores = []
history = []
lim = 0
count = 0
for train, test in kfold.split(X, Y):
    y_cat = to_categorical(Y).astype(int)
    print('k = ', count)
    count += 1
    # model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    h = model.fit(X[train] ,y_cat[train], epochs = ep,
                    batch_size = bs, 
                    validation_data = [X[test], y_cat[test]],
                    )
                      # callbacks = [earlystopper])
#                     callbacks=[checkpointer, earlystopper, tensorboard])

    history.append(h)
    # evaluate the model
    scores = model.evaluate(X[test], y_cat[test], verbose=1)
    if scores[1]>lim:
        lim = scores[1]
        filename = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
        pickle.dump(model, open(filename, 'wb'))
        model.save('Najadat')
    filename = '/content/drive/My Drive/Notebook/Training_Files/Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'_k'+str(count)+'.pkl'
    pickle.dump(model, open(filename, 'wb'))
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)
print("%.2f%% (+/- %.2f%%)" % (numpy.mean(cvscores), numpy.std(cvscores)))
# Out:
# k =  0
# Train on 1161 samples, validate on 291 samples
# Epoch 1/50
# 1161/1161 [==============================] - 1s 968us/step - loss: 4.5954 - accuracy: 0.0586 - val_loss: 4.1270 - val_accuracy: 0.0653
# Epoch 2/50
# 1161/1161 [==============================] - 1s 489us/step - loss: 3.7385 - accuracy: 0.1404 - val_loss: 3.8967 - val_accuracy: 0.0447
# Epoch 3/50
# 1161/1161 [==============================] - 1s 479us/step - loss: 3.2193 - accuracy: 0.2627 - val_loss: 3.7511 - val_accuracy: 0.1478
# Epoch 4/50
# 1161/1161 [==============================] - 1s 507us/step - loss: 2.7767 - accuracy: 0.3842 - val_loss: 3.3483 - val_accuracy: 0.2577
# Epoch 5/50
# 1161/1161 [==============================] - 1s 481us/step - loss: 2.5304 - accuracy: 0.4229 - val_loss: 3.0794 - val_accuracy: 0.4261
# Epoch 6/50
# 1161/1161 [==============================] - 1s 463us/step - loss: 2.2289 - accuracy: 0.4901 - val_loss: 2.6012 - val_accuracy: 0.5120
# Epoch 7/50
# 1161/1161 [==============================] - 1s 462us/step - loss: 1.9804 - accuracy: 0.5616 - val_loss: 2.3025 - val_accuracy: 0.5636
# Epoch 8/50
# 1161/1161 [==============================] - 1s 475us/step - loss: 1.7727 - accuracy: 0.6184 - val_loss: 2.1322 - val_accuracy: 0.5395
# Epoch 9/50
# 1161/1161 [==============================] - 1s 476us/step - loss: 1.5124 - accuracy: 0.6865 - val_loss: 1.8007 - val_accuracy: 0.6289
# Epoch 10/50
# 1161/1161 [==============================] - 1s 487us/step - loss: 1.3771 - accuracy: 0.7123 - val_loss: 1.5906 - val_accuracy: 0.6254
# Epoch 11/50
# 1161/1161 [==============================] - 1s 488us/step - loss: 1.2190 - accuracy: 0.7717 - val_loss: 1.6441 - val_accuracy: 0.6117
# Epoch 12/50
# 1161/1161 [==============================] - 1s 489us/step - loss: 1.0697 - accuracy: 0.8114 - val_loss: 1.3542 - val_accuracy: 0.6735
# Epoch 13/50
# 1161/1161 [==============================] - 1s 510us/step - loss: 0.9803 - accuracy: 0.8260 - val_loss: 1.2936 - val_accuracy: 0.7216
# Epoch 14/50
# 1161/1161 [==============================] - 1s 470us/step - loss: 0.8915 - accuracy: 0.8346 - val_loss: 1.2585 - val_accuracy: 0.7113
# Epoch 15/50
# 1161/1161 [==============================] - 1s 490us/step - loss: 0.7394 - accuracy: 0.8717 - val_loss: 1.2202 - val_accuracy: 0.7388
# Epoch 16/50
# 1161/1161 [==============================] - 1s 499us/step - loss: 0.7082 - accuracy: 0.8949 - val_loss: 1.2252 - val_accuracy: 0.7251
# Epoch 17/50
# 1161/1161 [==============================] - 1s 493us/step - loss: 0.7189 - accuracy: 0.8717 - val_loss: 1.1770 - val_accuracy: 0.7182
# Epoch 18/50
# 1161/1161 [==============================] - 1s 491us/step - loss: 0.5892 - accuracy: 0.9199 - val_loss: 1.0676 - val_accuracy: 0.7595
# Epoch 33/50
# 1162/1162 [==============================] - 1s 479us/step - loss: 0.1319 - accuracy: 0.9888 - val_loss: 0.1118 - val_accuracy: 0.9862
# Epoch 34/50
# 1162/1162 [==============================] - 1s 478us/step - loss: 0.1300 - accuracy: 0.9845 - val_loss: 0.1501 - val_accuracy: 0.9793
# Epoch 35/50
# 1162/1162 [==============================] - 1s 466us/step - loss: 0.1513 - accuracy: 0.9776 - val_loss: 0.1475 - val_accuracy: 0.9759
# Epoch 36/50
# 1162/1162 [==============================] - 1s 473us/step - loss: 0.1412 - accuracy: 0.9836 - val_loss: 0.1328 - val_accuracy: 0.9759
# Epoch 37/50
# 1162/1162 [==============================] - 1s 481us/step - loss: 0.1295 - accuracy: 0.9845 - val_loss: 0.1601 - val_accuracy: 0.9690
# Epoch 38/50
# 1162/1162 [==============================] - 1s 476us/step - loss: 0.1096 - accuracy: 0.9923 - val_loss: 0.1265 - val_accuracy: 0.9828
# Epoch 39/50
# 1162/1162 [==============================] - 1s 482us/step - loss: 0.1211 - accuracy: 0.9836 - val_loss: 0.2023 - val_accuracy: 0.9621
# Epoch 40/50
# 1162/1162 [==============================] - 1s 471us/step - loss: 0.1248 - accuracy: 0.9836 - val_loss: 0.1835 - val_accuracy: 0.9759
# Epoch 41/50
# 1162/1162 [==============================] - 1s 478us/step - loss: 0.1177 - accuracy: 0.9888 - val_loss: 0.1488 - val_accuracy: 0.9724
# Epoch 42/50
# 1162/1162 [==============================] - 1s 470us/step - loss: 0.1086 - accuracy: 0.9914 - val_loss: 0.1269 - val_accuracy: 0.9828
# Epoch 43/50
# 1162/1162 [==============================] - 1s 476us/step - loss: 0.1204 - accuracy: 0.9854 - val_loss: 0.1561 - val_accuracy: 0.9828
# Epoch 44/50
# 1162/1162 [==============================] - 1s 506us/step - loss: 0.1113 - accuracy: 0.9862 - val_loss: 0.1394 - val_accuracy: 0.9759
# Epoch 45/50
# 1162/1162 [==============================] - 1s 506us/step - loss: 0.1002 - accuracy: 0.9888 - val_loss: 0.2242 - val_accuracy: 0.9448
# Epoch 46/50
# 1162/1162 [==============================] - 1s 503us/step - loss: 0.1245 - accuracy: 0.9828 - val_loss: 0.1703 - val_accuracy: 0.9759
# Epoch 47/50
# 1162/1162 [==============================] - 1s 459us/step - loss: 0.1238 - accuracy: 0.9854 - val_loss: 0.2198 - val_accuracy: 0.9483
# Epoch 48/50
# 1162/1162 [==============================] - 1s 483us/step - loss: 0.1965 - accuracy: 0.9578 - val_loss: 0.2591 - val_accuracy: 0.9241
# Epoch 49/50
# 1162/1162 [==============================] - 1s 495us/step - loss: 0.1929 - accuracy: 0.9544 - val_loss: 0.3143 - val_accuracy: 0.9379
# Epoch 50/50
# 1162/1162 [==============================] - 1s 490us/step - loss: 0.1986 - accuracy: 0.9647 - val_loss: 0.2782 - val_accuracy: 0.9379
# 290/290 [==============================] - 0s 93us/step
# accuracy: 93.79%
# k =  3
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# Epoch 40/50
# 1162/1162 [==============================] - 1s 479us/step - loss: 0.0843 - accuracy: 0.9974 - val_loss: 0.0921 - val_accuracy: 0.9931
# Epoch 41/50
# 1162/1162 [==============================] - 1s 469us/step - loss: 0.0887 - accuracy: 0.9923 - val_loss: 0.1096 - val_accuracy: 0.9828
# Epoch 42/50
# 1162/1162 [==============================] - 1s 478us/step - loss: 0.1196 - accuracy: 0.9802 - val_loss: 0.1481 - val_accuracy: 0.9724
# Epoch 43/50
# 1162/1162 [==============================] - 1s 479us/step - loss: 0.1475 - accuracy: 0.9785 - val_loss: 0.1308 - val_accuracy: 0.9793
# Epoch 44/50
# 1162/1162 [==============================] - 1s 495us/step - loss: 0.1740 - accuracy: 0.9707 - val_loss: 0.1806 - val_accuracy: 0.9724
# Epoch 45/50
# 1162/1162 [==============================] - 1s 485us/step - loss: 0.1803 - accuracy: 0.9682 - val_loss: 0.1669 - val_accuracy: 0.9724
# Epoch 46/50
# 1162/1162 [==============================] - 1s 476us/step - loss: 0.2187 - accuracy: 0.9639 - val_loss: 0.2103 - val_accuracy: 0.9655
# Epoch 47/50
# 1162/1162 [==============================] - 1s 485us/step - loss: 0.1965 - accuracy: 0.9690 - val_loss: 0.1393 - val_accuracy: 0.9828
# Epoch 48/50
# 1162/1162 [==============================] - 1s 482us/step - loss: 0.1722 - accuracy: 0.9699 - val_loss: 0.2523 - val_accuracy: 0.9448
# Epoch 49/50
# 1162/1162 [==============================] - 1s 488us/step - loss: 0.1847 - accuracy: 0.9682 - val_loss: 0.1927 - val_accuracy: 0.9655
# Epoch 50/50
# 1162/1162 [==============================] - 1s 483us/step - loss: 0.1234 - accuracy: 0.9871 - val_loss: 0.1483 - val_accuracy: 0.9759
# 290/290 [==============================] - 0s 90us/step
# accuracy: 97.59%
# k =  4
# Train on 1162 samples, validate on 290 samples
# Epoch 1/50
# 1162/1162 [==============================] - 1s 506us/step - loss: 0.1814 - accuracy: 0.9750 - val_loss: 0.0903 - val_accuracy: 0.9966
# Epoch 2/50
# 1162/1162 [==============================] - 1s 482us/step - loss: 0.1839 - accuracy: 0.9733 - val_loss: 0.0916 - val_accuracy: 0.9966
# Epoch 3/50
# 1162/1162 [==============================] - 1s 503us/step - loss: 0.1829 - accuracy: 0.9682 - val_loss: 0.0875 - val_accuracy: 0.9966
# Epoch 4/50
# 1162/1162 [==============================] - 1s 496us/step - loss: 0.1295 - accuracy: 0.9845 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 5/50
# 1162/1162 [==============================] - 1s 469us/step - loss: 0.1343 - accuracy: 0.9828 - val_loss: 0.0942 - val_accuracy: 0.9931
# Epoch 6/50
# 1162/1162 [==============================] - 1s 503us/step - loss: 0.1251 - accuracy: 0.9845 - val_loss: 0.0954 - val_accuracy: 0.9931
# Epoch 7/50
# 1162/1162 [==============================] - 1s 497us/step - loss: 0.1659 - accuracy: 0.9682 - val_loss: 0.1103 - val_accuracy: 0.9966
# Epoch 8/50
# Epoch 47/50
# 1162/1162 [==============================] - 1s 466us/step - loss: 0.1875 - accuracy: 0.9647 - val_loss: 0.2397 - val_accuracy: 0.9655
# Epoch 48/50
# 1162/1162 [==============================] - 1s 476us/step - loss: 0.1433 - accuracy: 0.9828 - val_loss: 0.1869 - val_accuracy: 0.9690
# Epoch 49/50
# 1162/1162 [==============================] - 1s 479us/step - loss: 0.1274 - accuracy: 0.9845 - val_loss: 0.1321 - val_accuracy: 0.9862
# Epoch 50/50
# 1162/1162 [==============================] - 1s 463us/step - loss: 0.1200 - accuracy: 0.9888 - val_loss: 0.1024 - val_accuracy: 0.9931
# 290/290 [==============================] - 0s 85us/step
# accuracy: 99.31%
# 92.30% (+/- 7.03%)
# CPU times: user 2min 59s, sys: 18.1 s, total: 3min 17s
# Wall time: 2min 23s

# %%
# summarize history for accuracy
sns.reset_orig()
filename = '/content/drive/My Drive/Notebook/Training_Files/history_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
pickle.dump(history, open(filename, 'wb'))
c = 1
for h in history:
    print('k = ', c)
    c += 1
    plt.plot(h.history['accuracy'])
    plt.plot(h.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(h.history['loss'])
    plt.plot(h.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
# Out:
# k =  1
# k =  2
# k =  3
# k =  4
# k =  5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

model_name = '/content/drive/My Drive/Notebook/Training_Files/best_model_Najadat_'+str(dtype)+'_'+str(ep)+'_'+str(bs)+'.pkl'
model = pickle.load(open(model_name, 'rb'))
y_pred = model.predict(data_test)
y_pred = np.argmax(y_pred, axis = 1)

print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
sns.set(rc={'figure.figsize':(9,8)})
heatmap = sns.heatmap(cm, annot=True, cmap='Blues',
            xticklabels=char_list_nameonly, yticklabels=char_list_nameonly, cbar=False)
heatmap.set(ylabel='True', xlabel='Predicted')
plot_cm = heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.85        11
#            1       0.57      0.87      0.68        15
#            2       0.92      0.88      0.90        25
#            3       0.81      0.68      0.74        19
#            4       0.91      0.87      0.89        23
#            5       0.75      0.75      0.75        24
#            6       0.80      0.76      0.78        21
#            7       1.00      1.00      1.00         2
#            8       1.00      0.50      0.67         2
#            9       0.33      0.50      0.40         2
#           10       1.00      1.00      1.00         3
#           11       0.80      1.00      0.89         8
#           12       0.93      0.88      0.90        16
#           13       0.85      1.00      0.92        11
#           14       1.00      0.73      0.84        11
#           15       1.00      0.73      0.84        11
#           16       1.00      0.80      0.89         5
#           17       0.64      0.58      0.61        12
#           18       0.82      0.90      0.86        10
#           19       0.90      0.90      0.90        10
#           20       0.83      0.91      0.87        11
#           21       0.85      0.92      0.88        12
#           22       0.76      0.89      0.82        18
#           23       0.81      0.71      0.76        24
#           24       0.68      0.88      0.77        17
#           25       1.00      1.00      1.00         3
#           26       0.88      0.78      0.82         9
#           27       0.90      0.64      0.75        28
#
#     accuracy                           0.81       363
#    macro avg       0.84      0.82      0.82       363
# weighted avg       0.83      0.81      0.81       363
